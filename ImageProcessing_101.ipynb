# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read an image with matplotlib

# %%
image = plt.imread('images/devon.jpg')
plt.imshow(image)

plt.show()

# %%
image
# Out:
# array([[[144, 169, 209],
#         [144, 169, 209],
#         [145, 170, 210],
#         ...,
#         [157, 181, 229],
#         [155, 179, 227],
#         [153, 177, 225]],
#
#        [[147, 172, 212],
#         [147, 172, 212],
#         [147, 172, 212],
#         ...,
#         [156, 180, 228],
#         [155, 179, 227],
#         [155, 179, 227]],
#
#        [[148, 173, 213],
#         [148, 173, 213],
#         [148, 173, 213],
#         ...,
#         [154, 178, 226],
#         [154, 178, 226],
#         [155, 179, 227]],
#
#        ...,
#
#        [[ 55,  69,  16],
#         [ 60,  75,  18],
#         [ 63,  79,  17],
#         ...,
#         [105, 121,  56],
#         [137, 139,  89],
#         [160, 152, 113]],
#
#        [[ 58,  72,  19],
#         [ 64,  79,  22],
#         [ 69,  85,  23],
#         ...,
#         [101, 117,  52],
#         [143, 145,  95],
#         [190, 183, 141]],
#
#        [[ 77,  91,  38],
#         [ 84,  99,  42],
#         [ 76,  92,  30],
#         ...,
#         [ 89, 105,  40],
#         [129, 131,  81],
#         [190, 183, 141]]], dtype=uint8)

# %%
image.ndim
# Out:
# 3

# %%
image.shape
# Out:
# (360, 480, 3)

# %% [markdown]
# ### Read an image in black and white

# %%
image2 = plt.imread('images/zero.jpg')
plt.imshow(image2)
plt.show()

# %%
plt.imshow(image2, cmap = "gray")
plt.show()

# %%
image2
# Out:
# array([[  2,   0,   2,   0,   0,   2,   3,   3,   5,   2,   0],
#        [  0,   2,   0,   7,   6, 247, 253,   0,   0,   2,   0],
#        [  0,   0,   8,   0, 249, 255, 255, 255,  73,   2,   7],
#        [  3,   0,   1, 254, 253,   3,   0, 251, 255,   0,   2],
#        [  0,   3,   0, 254,   3,   0,   2,   2, 255,   4,   0],
#        [  0,   4,   0, 255,   1,   2,   0,   2, 253,   0,   6],
#        [  1,   6,   5, 245,   6,   0,   0,   1, 255,   2,   0],
#        [  0,   0,   1,   0,   3,   1,   7,   0, 254,   0,   6],
#        [  0,   0,   0, 255,   2,   0,   1,   4, 254,   1,   0],
#        [  2,   6,   1, 252,   1,   2,   1,  75, 250,   8,   0],
#        [  0,   0,   4,   1, 253,   1,   0, 255, 255,   0,   2],
#        [  1,  10,   0,   4, 253, 253, 255, 248,   1,   1,   1],
#        [  3,   0,   1,   0,   8,   0,   4,   0,   5,   0,   0]],
#       dtype=uint8)

# %% [markdown]
# ### Modify an image

# %%
image2[0, 0]
# Out:
# 2

# %%
image2[0, 0] = 255

# %%
image2
# Out:
# array([[255,   0,   2,   0,   0,   2,   3,   3,   5,   2,   0],
#        [  0,   2,   0,   7,   6, 247, 253,   0,   0,   2,   0],
#        [  0,   0,   8,   0, 249, 255, 255, 255,  73,   2,   7],
#        [  3,   0,   1, 254, 253,   3,   0, 251, 255,   0,   2],
#        [  0,   3,   0, 254,   3,   0,   2,   2, 255,   4,   0],
#        [  0,   4,   0, 255,   1,   2,   0,   2, 253,   0,   6],
#        [  1,   6,   5, 245,   6,   0,   0,   1, 255,   2,   0],
#        [  0,   0,   1,   0,   3,   1,   7,   0, 254,   0,   6],
#        [  0,   0,   0, 255,   2,   0,   1,   4, 254,   1,   0],
#        [  2,   6,   1, 252,   1,   2,   1,  75, 250,   8,   0],
#        [  0,   0,   4,   1, 253,   1,   0, 255, 255,   0,   2],
#        [  1,  10,   0,   4, 253, 253, 255, 248,   1,   1,   1],
#        [  3,   0,   1,   0,   8,   0,   4,   0,   5,   0,   0]],
#       dtype=uint8)

# %%
plt.imshow(image2, cmap = "gray")
plt.show()
