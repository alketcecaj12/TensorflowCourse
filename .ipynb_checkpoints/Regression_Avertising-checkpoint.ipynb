# %%
import numpy as np
import tensorflow as tf 
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.utils import plot_model

# %%
ad = pd.read_csv('dati/Advertising.csv')
ad
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
ad.to_csv("dati/Advertising.csv", index = False)

# %%
ad
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
plt.scatter(ad['TV'], ad['Sales'])
plt.show()

# %%
plt.scatter(ad['Radio'], ad['Sales'])
plt.show()

# %%
plt.scatter(ad['Newspaper'],ad['Sales'])
plt.show()

# %%
ad['TV'].corr(ad['Sales'])
# Out:
# 0.7822244248616066

# %%
ad.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
X = ad[['TV', 'Radio', 'Newspaper']].values
y =  ad['Sales'].values

# %%
# Instantiate a Sequential model
model = tf.keras.models.Sequential()

# Add three Dense layers with a given number of neurons and relu activation function
model.add(tf.keras.layers.Dense(500, input_shape=(3,),activation='relu'))
model.add(tf.keras.layers.Dense(100, input_shape=(1,),activation='relu'))
model.add(tf.keras.layers.Dense(50, input_shape=(1,),activation='relu'))

# End your model with a Dense layer and no activation
model.add(tf.keras.layers.Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 500)               2000
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               50100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# ...
# Total params: 57,201
# Trainable params: 57,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile your model
model.compile(optimizer = 'adam', loss = 'mse')

# Fit your model on your data for 30 epochs
history = model.fit(X, y, epochs = 500)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 0s 4ms/step - loss: 33.5512
# Epoch 2/500
# 7/7 [==============================] - 0s 2ms/step - loss: 10.4556
# Epoch 3/500
# 7/7 [==============================] - 0s 2ms/step - loss: 4.2155
# Epoch 4/500
# 7/7 [==============================] - 0s 2ms/step - loss: 3.8754
# Epoch 5/500
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1861
# Epoch 6/500
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1270
# Epoch 7/500
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8446
# Epoch 8/500
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8281
# Epoch 9/500
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0477
# Epoch 10/500
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6264
# Epoch 11/500
# 7/7 [==============================] - 0s 2ms/step - loss: 2.7813
# Epoch 12/500
# 7/7 [==============================] - 0s 2ms/step - loss: 2.7901
# ...

# %%
plt.figure(figsize = (20, 4))
plt.plot(history.history['loss'])
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.show()

# %%
model.predict([[300, 50, 70]])
# Out:
# array([[27.658972]], dtype=float32)

# %%
plot_model(model, to_file="lenet.png", show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
