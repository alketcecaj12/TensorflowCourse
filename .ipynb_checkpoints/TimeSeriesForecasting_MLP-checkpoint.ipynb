# %% [markdown]
# ### Perform Forecasts with a Multilayer Perceptron Neural Network.

# %%
import tensorflow 
print('Tensorflow Version : ', tensorflow.__version__)
# Out:
# Tensorflow Version :  2.5.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import metrics

# %%
# load the data 
trs = pd.read_csv("data/transactions.csv")
trs['date'] = pd.to_datetime(trs['date'])
trs['date'] = pd.to_datetime(trs['date'])
t2day = trs['date'].value_counts().sort_values()
t2day = t2day.to_frame()
series = X = t2day.date.sort_index().values

# %% [markdown]
# ### Visualizing data

# %%
plt.figure(figsize = (20, 6))
plt.xlabel("Time")
plt.ylabel("Transactions")

plt.plot(t2day.date.sort_index())
plt.show()

# %% [markdown]
# ### How to prepare the data for the neural network.
#
# <img src = "img/Multistep.png" alt="Girl in a jacket" width="600" height="800">

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
         # find the end of this pattern
         end_ix = i + n_steps_in
         out_end_ix = end_ix + n_steps_out
         # check if we are beyond the sequence
         if out_end_ix > len(sequence):
             break
         # gather input and output parts of the pattern
         seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
         X.append(seq_x)
         y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 90,30

# split into samples
X, y = split_sequence(series, n_steps_in, n_steps_out)
count = 0
for i in range(len(X)):
    print(series[i],X[i], y[i])
    count +=1
    if count>7: break
# Out:
# 7 [ 7  8  3  7  4  1  5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7
#   6  1  7  7  5  3  9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8
#  12  7  2  4  4  7  2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4
#   7  5  6 11  3  1 10  6  1  6  6  5  1  4  1  2  7 13] [ 8  7  7 17  3  2  7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10
#   8  3  6  6 13  4]
# 8 [ 8  3  7  4  1  5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6
#   1  7  7  5  3  9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12
#   7  2  4  4  7  2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7
#   5  6 11  3  1 10  6  1  6  6  5  1  4  1  2  7 13  8] [ 7  7 17  3  2  7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8
#   3  6  6 13  4 13]
# 3 [ 3  7  4  1  5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6  1
#   7  7  5  3  9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12  7
#   2  4  4  7  2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7  5
#   6 11  3  1 10  6  1  6  6  5  1  4  1  2  7 13  8  7] [ 7 17  3  2  7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8  3
#   6  6 13  4 13  2]
# 7 [ 7  4  1  5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6  1  7
#   7  5  3  9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12  7  2
#   4  4  7  2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7  5  6
#  11  3  1 10  6  1  6  6  5  1  4  1  2  7 13  8  7  7] [17  3  2  7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8  3  6
#   6 13  4 13  2  1]
# 4 [ 4  1  5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6  1  7  7
#   5  3  9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12  7  2  4
#   4  7  2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7  5  6 11
#   3  1 10  6  1  6  6  5  1  4  1  2  7 13  8  7  7 17] [ 3  2  7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8  3  6  6
#  13  4 13  2  1 10]
# 1 [ 1  5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6  1  7  7  5
#   3  9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12  7  2  4  4
#   7  2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7  5  6 11  3
#   1 10  6  1  6  6  5  1  4  1  2  7 13  8  7  7 17  3] [ 2  7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8  3  6  6 13
#   4 13  2  1 10 16]
# 5 [ 5 11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6  1  7  7  5  3
#   9  2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12  7  2  4  4  7
#   2  4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7  5  6 11  3  1
#  10  6  1  6  6  5  1  4  1  2  7 13  8  7  7 17  3  2] [ 7  2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8  3  6  6 13  4
#  13  2  1 10 16  5]
# 11 [11  8  1  7  1  2  4  1 12  6  6  4  4  2  6  6  7  6  1  7  7  5  3  9
#   2  8  3  3  8  6  3  1  4 12  2  2  7  4  2  9  8 12  7  2  4  4  7  2
#   4  5  4  1  6 11  8  3 10 10 10 10  3  6  4  4  4  7  5  6 11  3  1 10
#   6  1  6  6  5  1  4  1  2  7 13  8  7  7 17  3  2  7] [ 2  2 10  1  4  4  3  3  7 10  2  3  5  1  2 13 10  8  3  6  6 13  4 13
#   2  1 10 16  5  7]

# %%
print(X.shape)
print(y.shape)
# Out:
# (1113, 90)
# (1113, 30)

# %%
train_size = 800
test_size = 223

train_X, test_X = X[:train_size], X[train_size:] 
train_y, test_y = y[:train_size], y[train_size:]

# %%
# define model
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=n_steps_in)) 
model.add(Dense(250, activation='relu', input_dim=n_steps_in)) 
model.add(Dense(n_steps_out))

model.compile(optimizer='adam', loss='mse' , metrics=[metrics.mae])

# fit model
history = model.fit(train_X, train_y, batch_size=128, epochs=250, verbose=2)
# Out:
# Epoch 1/250
# 7/7 - 0s - loss: 41118.1094 - mean_absolute_error: 117.5143
# Epoch 2/250
# 7/7 - 0s - loss: 14602.5674 - mean_absolute_error: 70.5329
# Epoch 3/250
# 7/7 - 0s - loss: 11045.2217 - mean_absolute_error: 63.2660
# Epoch 4/250
# 7/7 - 0s - loss: 8443.8096 - mean_absolute_error: 54.4198
# Epoch 5/250
# 7/7 - 0s - loss: 6725.7520 - mean_absolute_error: 48.4261
# Epoch 6/250
# 7/7 - 0s - loss: 5594.5112 - mean_absolute_error: 43.3224
# Epoch 7/250
# 7/7 - 0s - loss: 4981.2627 - mean_absolute_error: 40.8651
# Epoch 8/250
# 7/7 - 0s - loss: 4517.8843 - mean_absolute_error: 38.2677
# Epoch 9/250
# 7/7 - 0s - loss: 4208.3574 - mean_absolute_error: 36.8228
# Epoch 10/250
# 7/7 - 0s - loss: 4093.7615 - mean_absolute_error: 36.9416
# Epoch 11/250
# 7/7 - 0s - loss: 3720.4744 - mean_absolute_error: 35.0979
# Epoch 12/250
# 7/7 - 0s - loss: 3586.9844 - mean_absolute_error: 34.4585
# Epoch 13/250
# 7/7 - 0s - loss: 3476.7764 - mean_absolute_error: 33.6962
# Epoch 14/250
# 7/7 - 0s - loss: 3660.8813 - mean_absolute_error: 35.2796
# Epoch 15/250
# 7/7 - 0s - loss: 3327.1514 - mean_absolute_error: 33.6719
# Epoch 16/250
# 7/7 - 0s - loss: 3243.6404 - mean_absolute_error: 33.0886
# Epoch 17/250
# 7/7 - 0s - loss: 3213.9006 - mean_absolute_error: 32.8666
# Epoch 18/250
# 7/7 - 0s - loss: 3185.9490 - mean_absolute_error: 33.0734
# Epoch 19/250
# 7/7 - 0s - loss: 3179.5410 - mean_absolute_error: 33.3836
# Epoch 20/250
# 7/7 - 0s - loss: 3145.0042 - mean_absolute_error: 32.9591
# Epoch 21/250
# 7/7 - 0s - loss: 3139.0007 - mean_absolute_error: 32.7976
# Epoch 22/250
# 7/7 - 0s - loss: 2988.8005 - mean_absolute_error: 32.1005
# Epoch 23/250
# 7/7 - 0s - loss: 2878.8809 - mean_absolute_error: 31.7030
# Epoch 24/250
# 7/7 - 0s - loss: 2929.8027 - mean_absolute_error: 32.0000
# Epoch 25/250
# 7/7 - 0s - loss: 2861.4490 - mean_absolute_error: 31.6179
# Epoch 26/250
# 7/7 - 0s - loss: 2769.8757 - mean_absolute_error: 31.2576
# Epoch 27/250
# 7/7 - 0s - loss: 2755.3694 - mean_absolute_error: 31.2260
# Epoch 28/250
# 7/7 - 0s - loss: 2746.1777 - mean_absolute_error: 31.2283
# Epoch 29/250
# 7/7 - 0s - loss: 2707.0569 - mean_absolute_error: 30.9519
# Epoch 30/250
# 7/7 - 0s - loss: 2711.5979 - mean_absolute_error: 31.3796
# Epoch 31/250
# 7/7 - 0s - loss: 2630.1399 - mean_absolute_error: 30.9296
# Epoch 32/250
# 7/7 - 0s - loss: 2606.2139 - mean_absolute_error: 30.8256
# Epoch 33/250
# 7/7 - 0s - loss: 2753.0186 - mean_absolute_error: 31.6743
# Epoch 34/250
# 7/7 - 0s - loss: 2713.1394 - mean_absolute_error: 31.5073
# Epoch 35/250
# 7/7 - 0s - loss: 2544.1538 - mean_absolute_error: 30.4774
# Epoch 36/250
# 7/7 - 0s - loss: 2537.2715 - mean_absolute_error: 30.5915
# Epoch 37/250
# 7/7 - 0s - loss: 2536.0215 - mean_absolute_error: 30.6180
# Epoch 38/250
# 7/7 - 0s - loss: 2490.0063 - mean_absolute_error: 30.5020
# Epoch 39/250
# 7/7 - 0s - loss: 2426.6521 - mean_absolute_error: 30.0340
# Epoch 40/250
# 7/7 - 0s - loss: 2440.1436 - mean_absolute_error: 30.1048
# Epoch 41/250
# 7/7 - 0s - loss: 2453.1138 - mean_absolute_error: 30.3008
# Epoch 42/250
# 7/7 - 0s - loss: 2397.9617 - mean_absolute_error: 30.1462
# Epoch 43/250
# 7/7 - 0s - loss: 2360.5681 - mean_absolute_error: 29.7995
# Epoch 44/250
# 7/7 - 0s - loss: 2283.7905 - mean_absolute_error: 29.4322
# Epoch 45/250
# 7/7 - 0s - loss: 2285.1638 - mean_absolute_error: 29.5890
# Epoch 46/250
# 7/7 - 0s - loss: 2272.8430 - mean_absolute_error: 29.5319
# Epoch 47/250
# 7/7 - 0s - loss: 2216.5181 - mean_absolute_error: 29.1395
# Epoch 48/250
# 7/7 - 0s - loss: 2240.3306 - mean_absolute_error: 29.3752
# Epoch 49/250
# 7/7 - 0s - loss: 2264.2305 - mean_absolute_error: 29.6216
# Epoch 50/250
# 7/7 - 0s - loss: 2340.9790 - mean_absolute_error: 29.9969
# Epoch 51/250
# 7/7 - 0s - loss: 2257.1147 - mean_absolute_error: 29.5131
# Epoch 52/250
# 7/7 - 0s - loss: 2162.5310 - mean_absolute_error: 29.1828
# Epoch 53/250
# 7/7 - 0s - loss: 2130.8433 - mean_absolute_error: 28.7848
# Epoch 54/250
# 7/7 - 0s - loss: 2192.6934 - mean_absolute_error: 29.3311
# Epoch 55/250
# 7/7 - 0s - loss: 2141.7671 - mean_absolute_error: 28.9420
# Epoch 56/250
# 7/7 - 0s - loss: 2129.6353 - mean_absolute_error: 28.9623
# Epoch 57/250
# 7/7 - 0s - loss: 2093.8647 - mean_absolute_error: 28.5735
# Epoch 58/250
# 7/7 - 0s - loss: 2030.5216 - mean_absolute_error: 28.1911
# Epoch 59/250
# 7/7 - 0s - loss: 2096.6565 - mean_absolute_error: 28.7370
# Epoch 60/250
# 7/7 - 0s - loss: 2088.4670 - mean_absolute_error: 28.7507
# Epoch 61/250
# 7/7 - 0s - loss: 2197.1814 - mean_absolute_error: 29.4070
# Epoch 62/250
# 7/7 - 0s - loss: 2103.6523 - mean_absolute_error: 29.0049
# Epoch 63/250
# 7/7 - 0s - loss: 2097.9783 - mean_absolute_error: 28.8071
# Epoch 64/250
# 7/7 - 0s - loss: 2043.5038 - mean_absolute_error: 28.4268
# Epoch 65/250
# 7/7 - 0s - loss: 2086.1873 - mean_absolute_error: 28.8371
# Epoch 66/250
# 7/7 - 0s - loss: 2069.4302 - mean_absolute_error: 28.6554
# Epoch 67/250
# 7/7 - 0s - loss: 1937.2456 - mean_absolute_error: 27.8300
# Epoch 68/250
# 7/7 - 0s - loss: 2062.0105 - mean_absolute_error: 28.8043
# Epoch 69/250
# 7/7 - 0s - loss: 2118.4878 - mean_absolute_error: 29.1032
# Epoch 70/250
# 7/7 - 0s - loss: 2099.8625 - mean_absolute_error: 29.0850
# Epoch 71/250
# 7/7 - 0s - loss: 1895.0916 - mean_absolute_error: 27.5415
# Epoch 72/250
# 7/7 - 0s - loss: 1827.5535 - mean_absolute_error: 27.1840
# Epoch 73/250
# 7/7 - 0s - loss: 1826.3108 - mean_absolute_error: 27.1440
# Epoch 74/250
# 7/7 - 0s - loss: 1816.3319 - mean_absolute_error: 27.1856
# Epoch 75/250
# 7/7 - 0s - loss: 1803.3215 - mean_absolute_error: 27.0634
# Epoch 76/250
# 7/7 - 0s - loss: 1834.4279 - mean_absolute_error: 27.3419
# Epoch 77/250
# 7/7 - 0s - loss: 1748.4189 - mean_absolute_error: 26.5760
# Epoch 78/250
# 7/7 - 0s - loss: 1733.7054 - mean_absolute_error: 26.6006
# Epoch 79/250
# 7/7 - 0s - loss: 1705.5409 - mean_absolute_error: 26.4083
# Epoch 80/250
# 7/7 - 0s - loss: 1691.1361 - mean_absolute_error: 26.2456
# Epoch 81/250
# 7/7 - 0s - loss: 1679.2738 - mean_absolute_error: 26.1647
# Epoch 82/250
# 7/7 - 0s - loss: 1655.7736 - mean_absolute_error: 26.0128
# Epoch 83/250
# 7/7 - 0s - loss: 1719.2937 - mean_absolute_error: 26.6164
# Epoch 84/250
# 7/7 - 0s - loss: 1668.2931 - mean_absolute_error: 26.3097
# Epoch 85/250
# 7/7 - 0s - loss: 1648.5074 - mean_absolute_error: 26.0652
# Epoch 86/250
# 7/7 - 0s - loss: 1638.7533 - mean_absolute_error: 26.0202
# Epoch 87/250
# 7/7 - 0s - loss: 1591.7319 - mean_absolute_error: 25.6352
# Epoch 88/250
# 7/7 - 0s - loss: 1617.3678 - mean_absolute_error: 25.7970
# Epoch 89/250
# 7/7 - 0s - loss: 1550.3533 - mean_absolute_error: 25.4212
# Epoch 90/250
# 7/7 - 0s - loss: 1544.7952 - mean_absolute_error: 25.4101
# Epoch 91/250
# 7/7 - 0s - loss: 1530.3813 - mean_absolute_error: 25.2983
# Epoch 92/250
# 7/7 - 0s - loss: 1556.3389 - mean_absolute_error: 25.4058
# Epoch 93/250
# 7/7 - 0s - loss: 1547.8605 - mean_absolute_error: 25.4025
# Epoch 94/250
# 7/7 - 0s - loss: 1543.0437 - mean_absolute_error: 25.5236
# Epoch 95/250
# 7/7 - 0s - loss: 1568.7550 - mean_absolute_error: 25.6747
# Epoch 96/250
# 7/7 - 0s - loss: 1576.9230 - mean_absolute_error: 25.7343
# Epoch 97/250
# 7/7 - 0s - loss: 1506.5033 - mean_absolute_error: 25.1364
# Epoch 98/250
# 7/7 - 0s - loss: 1464.2271 - mean_absolute_error: 24.8552
# Epoch 99/250
# 7/7 - 0s - loss: 1478.2933 - mean_absolute_error: 25.0118
# Epoch 100/250
# 7/7 - 0s - loss: 1516.4006 - mean_absolute_error: 25.3215
# Epoch 101/250
# 7/7 - 0s - loss: 1520.8628 - mean_absolute_error: 25.2880
# Epoch 102/250
# 7/7 - 0s - loss: 1510.3566 - mean_absolute_error: 25.3163
# Epoch 103/250
# 7/7 - 0s - loss: 1464.1676 - mean_absolute_error: 24.8615
# Epoch 104/250
# 7/7 - 0s - loss: 1427.1937 - mean_absolute_error: 24.6099
# Epoch 105/250
# 7/7 - 0s - loss: 1407.6451 - mean_absolute_error: 24.4869
# Epoch 106/250
# 7/7 - 0s - loss: 1389.4017 - mean_absolute_error: 24.3308
# Epoch 107/250
# 7/7 - 0s - loss: 1403.5887 - mean_absolute_error: 24.5366
# Epoch 108/250
# 7/7 - 0s - loss: 1377.2440 - mean_absolute_error: 24.2795
# Epoch 109/250
# 7/7 - 0s - loss: 1365.9801 - mean_absolute_error: 24.1910
# Epoch 110/250
# 7/7 - 0s - loss: 1358.3864 - mean_absolute_error: 24.1849
# Epoch 111/250
# 7/7 - 0s - loss: 1336.1885 - mean_absolute_error: 23.9092
# Epoch 112/250
# 7/7 - 0s - loss: 1315.9208 - mean_absolute_error: 23.7994
# Epoch 113/250
# 7/7 - 0s - loss: 1342.7885 - mean_absolute_error: 23.9891
# Epoch 114/250
# 7/7 - 0s - loss: 1330.5308 - mean_absolute_error: 23.8910
# Epoch 115/250
# 7/7 - 0s - loss: 1377.3197 - mean_absolute_error: 24.2608
# Epoch 116/250
# 7/7 - 0s - loss: 1284.2358 - mean_absolute_error: 23.5869
# Epoch 117/250
# 7/7 - 0s - loss: 1282.8365 - mean_absolute_error: 23.5705
# Epoch 118/250
# 7/7 - 0s - loss: 1264.1313 - mean_absolute_error: 23.4147
# Epoch 119/250
# 7/7 - 0s - loss: 1249.9769 - mean_absolute_error: 23.3121
# Epoch 120/250
# 7/7 - 0s - loss: 1253.6749 - mean_absolute_error: 23.3234
# Epoch 121/250
# 7/7 - 0s - loss: 1246.2744 - mean_absolute_error: 23.2609
# Epoch 122/250
# 7/7 - 0s - loss: 1219.8529 - mean_absolute_error: 23.0670
# Epoch 123/250
# 7/7 - 0s - loss: 1193.7759 - mean_absolute_error: 22.8157
# Epoch 124/250
# 7/7 - 0s - loss: 1219.1222 - mean_absolute_error: 23.0764
# Epoch 125/250
# 7/7 - 0s - loss: 1209.0990 - mean_absolute_error: 22.9815
# Epoch 126/250
# 7/7 - 0s - loss: 1207.5400 - mean_absolute_error: 22.8978
# Epoch 127/250
# 7/7 - 0s - loss: 1159.9468 - mean_absolute_error: 22.5634
# Epoch 128/250
# 7/7 - 0s - loss: 1197.5814 - mean_absolute_error: 22.8700
# Epoch 129/250
# 7/7 - 0s - loss: 1165.6088 - mean_absolute_error: 22.5639
# Epoch 130/250
# 7/7 - 0s - loss: 1167.4385 - mean_absolute_error: 22.6162
# Epoch 131/250
# 7/7 - 0s - loss: 1159.5537 - mean_absolute_error: 22.5466
# Epoch 132/250
# 7/7 - 0s - loss: 1150.9609 - mean_absolute_error: 22.4632
# Epoch 133/250
# 7/7 - 0s - loss: 1136.8083 - mean_absolute_error: 22.3717
# Epoch 134/250
# 7/7 - 0s - loss: 1130.0396 - mean_absolute_error: 22.3284
# Epoch 135/250
# 7/7 - 0s - loss: 1176.9348 - mean_absolute_error: 22.6831
# Epoch 136/250
# 7/7 - 0s - loss: 1172.5902 - mean_absolute_error: 22.7041
# Epoch 137/250
# 7/7 - 0s - loss: 1175.0188 - mean_absolute_error: 22.7014
# Epoch 138/250
# 7/7 - 0s - loss: 1121.1902 - mean_absolute_error: 22.1789
# Epoch 139/250
# 7/7 - 0s - loss: 1116.2621 - mean_absolute_error: 22.2546
# Epoch 140/250
# 7/7 - 0s - loss: 1091.3629 - mean_absolute_error: 21.9974
# Epoch 141/250
# 7/7 - 0s - loss: 1071.9249 - mean_absolute_error: 21.8366
# Epoch 142/250
# 7/7 - 0s - loss: 1087.7179 - mean_absolute_error: 21.9914
# Epoch 143/250
# 7/7 - 0s - loss: 1073.2581 - mean_absolute_error: 21.8372
# Epoch 144/250
# 7/7 - 0s - loss: 1044.3430 - mean_absolute_error: 21.5463
# Epoch 145/250
# 7/7 - 0s - loss: 1020.9295 - mean_absolute_error: 21.2894
# Epoch 146/250
# 7/7 - 0s - loss: 1029.7946 - mean_absolute_error: 21.4207
# Epoch 147/250
# 7/7 - 0s - loss: 1023.8285 - mean_absolute_error: 21.3794
# Epoch 148/250
# 7/7 - 0s - loss: 1011.6599 - mean_absolute_error: 21.2211
# Epoch 149/250
# 7/7 - 0s - loss: 990.7463 - mean_absolute_error: 21.0445
# Epoch 150/250
# 7/7 - 0s - loss: 1006.4933 - mean_absolute_error: 21.2292
# Epoch 151/250
# 7/7 - 0s - loss: 1009.2165 - mean_absolute_error: 21.2307
# Epoch 152/250
# 7/7 - 0s - loss: 1020.2916 - mean_absolute_error: 21.4028
# Epoch 153/250
# 7/7 - 0s - loss: 1026.6448 - mean_absolute_error: 21.5205
# Epoch 154/250
# 7/7 - 0s - loss: 1029.1101 - mean_absolute_error: 21.4304
# Epoch 155/250
# 7/7 - 0s - loss: 981.3129 - mean_absolute_error: 21.0103
# Epoch 156/250
# 7/7 - 0s - loss: 964.1036 - mean_absolute_error: 20.8276
# Epoch 157/250
# 7/7 - 0s - loss: 949.4906 - mean_absolute_error: 20.6972
# Epoch 158/250
# 7/7 - 0s - loss: 942.9084 - mean_absolute_error: 20.6254
# Epoch 159/250
# 7/7 - 0s - loss: 949.5439 - mean_absolute_error: 20.6932
# Epoch 160/250
# 7/7 - 0s - loss: 1023.1841 - mean_absolute_error: 21.4695
# Epoch 161/250
# 7/7 - 0s - loss: 987.8767 - mean_absolute_error: 21.1311
# Epoch 162/250
# 7/7 - 0s - loss: 1028.0428 - mean_absolute_error: 21.5297
# Epoch 163/250
# 7/7 - 0s - loss: 1008.9127 - mean_absolute_error: 21.3468
# Epoch 164/250
# 7/7 - 0s - loss: 961.0610 - mean_absolute_error: 20.8374
# Epoch 165/250
# 7/7 - 0s - loss: 973.8096 - mean_absolute_error: 20.9954
# Epoch 166/250
# 7/7 - 0s - loss: 976.5812 - mean_absolute_error: 20.9961
# Epoch 167/250
# 7/7 - 0s - loss: 944.4653 - mean_absolute_error: 20.6476
# Epoch 168/250
# 7/7 - 0s - loss: 939.5008 - mean_absolute_error: 20.6687
# Epoch 169/250
# 7/7 - 0s - loss: 921.7154 - mean_absolute_error: 20.4631
# Epoch 170/250
# 7/7 - 0s - loss: 892.6041 - mean_absolute_error: 20.1757
# Epoch 171/250
# 7/7 - 0s - loss: 925.3268 - mean_absolute_error: 20.5658
# Epoch 172/250
# 7/7 - 0s - loss: 879.4055 - mean_absolute_error: 20.0208
# Epoch 173/250
# 7/7 - 0s - loss: 919.0703 - mean_absolute_error: 20.4927
# Epoch 174/250
# 7/7 - 0s - loss: 874.6470 - mean_absolute_error: 19.9672
# Epoch 175/250
# 7/7 - 0s - loss: 886.2477 - mean_absolute_error: 20.0855
# Epoch 176/250
# 7/7 - 0s - loss: 1044.7200 - mean_absolute_error: 21.8265
# Epoch 177/250
# 7/7 - 0s - loss: 1205.6136 - mean_absolute_error: 23.1427
# Epoch 178/250
# 7/7 - 0s - loss: 930.4920 - mean_absolute_error: 20.6098
# Epoch 179/250
# 7/7 - 0s - loss: 904.1044 - mean_absolute_error: 20.3217
# Epoch 180/250
# 7/7 - 0s - loss: 872.4489 - mean_absolute_error: 19.9447
# Epoch 181/250
# 7/7 - 0s - loss: 858.2788 - mean_absolute_error: 19.8600
# Epoch 182/250
# 7/7 - 0s - loss: 877.0920 - mean_absolute_error: 20.0633
# Epoch 183/250
# 7/7 - 0s - loss: 855.3718 - mean_absolute_error: 19.8144
# Epoch 184/250
# 7/7 - 0s - loss: 854.8334 - mean_absolute_error: 19.8132
# Epoch 185/250
# 7/7 - 0s - loss: 816.2012 - mean_absolute_error: 19.4274
# Epoch 186/250
# 7/7 - 0s - loss: 802.8278 - mean_absolute_error: 19.2076
# Epoch 187/250
# 7/7 - 0s - loss: 837.6633 - mean_absolute_error: 19.5844
# Epoch 188/250
# 7/7 - 0s - loss: 822.5449 - mean_absolute_error: 19.4680
# Epoch 189/250
# 7/7 - 0s - loss: 816.6702 - mean_absolute_error: 19.4503
# Epoch 190/250
# 7/7 - 0s - loss: 804.1949 - mean_absolute_error: 19.2596
# Epoch 191/250
# 7/7 - 0s - loss: 801.4645 - mean_absolute_error: 19.2499
# Epoch 192/250
# 7/7 - 0s - loss: 784.0725 - mean_absolute_error: 19.0296
# Epoch 193/250
# 7/7 - 0s - loss: 782.8576 - mean_absolute_error: 19.0275
# Epoch 194/250
# 7/7 - 0s - loss: 783.1286 - mean_absolute_error: 19.0925
# Epoch 195/250
# 7/7 - 0s - loss: 815.1736 - mean_absolute_error: 19.4385
# Epoch 196/250
# 7/7 - 0s - loss: 801.0454 - mean_absolute_error: 19.2437
# Epoch 197/250
# 7/7 - 0s - loss: 790.2802 - mean_absolute_error: 19.1652
# Epoch 198/250
# 7/7 - 0s - loss: 781.3051 - mean_absolute_error: 19.0127
# Epoch 199/250
# 7/7 - 0s - loss: 763.9667 - mean_absolute_error: 18.8342
# Epoch 200/250
# 7/7 - 0s - loss: 781.2928 - mean_absolute_error: 19.0662
# Epoch 201/250
# 7/7 - 0s - loss: 800.1412 - mean_absolute_error: 19.2740
# Epoch 202/250
# 7/7 - 0s - loss: 751.5449 - mean_absolute_error: 18.6866
# Epoch 203/250
# 7/7 - 0s - loss: 759.0941 - mean_absolute_error: 18.7275
# Epoch 204/250
# 7/7 - 0s - loss: 744.0171 - mean_absolute_error: 18.6039
# Epoch 205/250
# 7/7 - 0s - loss: 745.5590 - mean_absolute_error: 18.6434
# Epoch 206/250
# 7/7 - 0s - loss: 739.0312 - mean_absolute_error: 18.5380
# Epoch 207/250
# 7/7 - 0s - loss: 767.2701 - mean_absolute_error: 18.8480
# Epoch 208/250
# 7/7 - 0s - loss: 792.7745 - mean_absolute_error: 19.1485
# Epoch 209/250
# 7/7 - 0s - loss: 860.3736 - mean_absolute_error: 19.9412
# Epoch 210/250
# 7/7 - 0s - loss: 858.4886 - mean_absolute_error: 19.9045
# Epoch 211/250
# 7/7 - 0s - loss: 842.2720 - mean_absolute_error: 19.7768
# Epoch 212/250
# 7/7 - 0s - loss: 802.7450 - mean_absolute_error: 19.3326
# Epoch 213/250
# 7/7 - 0s - loss: 758.1262 - mean_absolute_error: 18.7885
# Epoch 214/250
# 7/7 - 0s - loss: 722.4897 - mean_absolute_error: 18.3942
# Epoch 215/250
# 7/7 - 0s - loss: 743.0719 - mean_absolute_error: 18.6700
# Epoch 216/250
# 7/7 - 0s - loss: 750.7687 - mean_absolute_error: 18.7106
# Epoch 217/250
# 7/7 - 0s - loss: 705.5438 - mean_absolute_error: 18.1668
# Epoch 218/250
# 7/7 - 0s - loss: 689.9168 - mean_absolute_error: 17.9862
# Epoch 219/250
# 7/7 - 0s - loss: 670.4576 - mean_absolute_error: 17.7139
# Epoch 220/250
# 7/7 - 0s - loss: 658.0528 - mean_absolute_error: 17.5120
# Epoch 221/250
# 7/7 - 0s - loss: 655.9178 - mean_absolute_error: 17.5544
# Epoch 222/250
# 7/7 - 0s - loss: 691.9231 - mean_absolute_error: 18.0312
# Epoch 223/250
# 7/7 - 0s - loss: 684.7606 - mean_absolute_error: 17.8761
# Epoch 224/250
# 7/7 - 0s - loss: 677.8247 - mean_absolute_error: 17.8112
# Epoch 225/250
# 7/7 - 0s - loss: 680.6176 - mean_absolute_error: 17.9006
# Epoch 226/250
# 7/7 - 0s - loss: 701.4274 - mean_absolute_error: 18.1116
# Epoch 227/250
# 7/7 - 0s - loss: 685.3120 - mean_absolute_error: 17.9584
# Epoch 228/250
# 7/7 - 0s - loss: 670.5323 - mean_absolute_error: 17.7702
# Epoch 229/250
# 7/7 - 0s - loss: 665.9126 - mean_absolute_error: 17.6981
# Epoch 230/250
# 7/7 - 0s - loss: 665.5907 - mean_absolute_error: 17.7164
# Epoch 231/250
# 7/7 - 0s - loss: 687.5095 - mean_absolute_error: 18.0149
# Epoch 232/250
# 7/7 - 0s - loss: 702.7983 - mean_absolute_error: 18.1821
# Epoch 233/250
# 7/7 - 0s - loss: 685.0359 - mean_absolute_error: 17.9823
# Epoch 234/250
# 7/7 - 0s - loss: 661.2729 - mean_absolute_error: 17.6739
# Epoch 235/250
# 7/7 - 0s - loss: 639.1098 - mean_absolute_error: 17.4186
# Epoch 236/250
# 7/7 - 0s - loss: 642.6625 - mean_absolute_error: 17.4547
# Epoch 237/250
# 7/7 - 0s - loss: 625.7866 - mean_absolute_error: 17.2091
# Epoch 238/250
# 7/7 - 0s - loss: 633.4671 - mean_absolute_error: 17.3104
# Epoch 239/250
# 7/7 - 0s - loss: 633.5286 - mean_absolute_error: 17.3217
# Epoch 240/250
# 7/7 - 0s - loss: 640.5579 - mean_absolute_error: 17.3887
# Epoch 241/250
# 7/7 - 0s - loss: 647.8394 - mean_absolute_error: 17.5136
# Epoch 242/250
# 7/7 - 0s - loss: 651.3715 - mean_absolute_error: 17.6025
# Epoch 243/250
# 7/7 - 0s - loss: 693.9590 - mean_absolute_error: 18.1848
# Epoch 244/250
# 7/7 - 0s - loss: 639.2991 - mean_absolute_error: 17.4002
# Epoch 245/250
# 7/7 - 0s - loss: 615.8629 - mean_absolute_error: 17.1902
# Epoch 246/250
# 7/7 - 0s - loss: 608.3745 - mean_absolute_error: 16.9878
# Epoch 247/250
# 7/7 - 0s - loss: 651.3229 - mean_absolute_error: 17.6055
# Epoch 248/250
# 7/7 - 0s - loss: 626.9602 - mean_absolute_error: 17.2590
# Epoch 249/250
# 7/7 - 0s - loss: 587.9326 - mean_absolute_error: 16.6994
# Epoch 250/250
# 7/7 - 0s - loss: 573.6503 - mean_absolute_error: 16.4633

# %%
history.history
# Out:
# {'loss': [41118.109375,
#   14602.5673828125,
#   11045.2216796875,
#   8443.8095703125,
#   6725.751953125,
#   5594.51123046875,
#   4981.2626953125,
#   4517.88427734375,
#   4208.357421875,
#   4093.761474609375,
#   3720.474365234375,
#   3586.984375,
#   3476.7763671875,
#   3660.88134765625,
#   3327.1513671875,
#   3243.640380859375,
#   3213.900634765625,
#   3185.948974609375,
#   3179.541015625,
#   3145.004150390625,
#   3139.000732421875,
#   2988.800537109375,
#   2878.880859375,
#   2929.802734375,
#   2861.448974609375,
#   2769.875732421875,
#   2755.369384765625,
#   2746.177734375,
#   2707.056884765625,
#   2711.597900390625,
#   2630.139892578125,
#   2606.2138671875,
#   2753.0185546875,
#   2713.139404296875,
#   2544.15380859375,
#   2537.271484375,
#   2536.021484375,
#   2490.00634765625,
#   2426.652099609375,
#   2440.1435546875,
#   2453.11376953125,
#   2397.961669921875,
#   2360.568115234375,
#   2283.79052734375,
#   2285.163818359375,
#   2272.843017578125,
#   2216.51806640625,
#   2240.33056640625,
#   2264.23046875,
#   2340.97900390625,
#   2257.11474609375,
#   2162.531005859375,
#   2130.84326171875,
#   2192.693359375,
#   2141.76708984375,
#   2129.63525390625,
#   2093.86474609375,
#   2030.5216064453125,
#   2096.656494140625,
#   2088.467041015625,
#   2197.181396484375,
#   2103.65234375,
#   2097.978271484375,
#   2043.5037841796875,
#   2086.187255859375,
#   2069.43017578125,
#   1937.24560546875,
#   2062.010498046875,
#   2118.48779296875,
#   2099.862548828125,
#   1895.091552734375,
#   1827.553466796875,
#   1826.310791015625,
#   1816.3319091796875,
#   1803.321533203125,
#   1834.4278564453125,
#   1748.4189453125,
#   1733.7054443359375,
#   1705.5408935546875,
#   1691.1361083984375,
#   1679.2738037109375,
#   1655.7735595703125,
#   1719.293701171875,
#   1668.2930908203125,
#   1648.5074462890625,
#   1638.7532958984375,
#   1591.73193359375,
#   1617.3677978515625,
#   1550.353271484375,
#   1544.795166015625,
#   1530.38134765625,
#   1556.3388671875,
#   1547.8604736328125,
#   1543.043701171875,
#   1568.7550048828125,
#   1576.9229736328125,
#   1506.5032958984375,
#   1464.22705078125,
#   1478.2933349609375,
#   1516.400634765625,
#   1520.86279296875,
#   1510.3565673828125,
#   1464.1676025390625,
#   1427.1937255859375,
#   1407.6451416015625,
#   1389.4017333984375,
#   1403.5887451171875,
#   1377.2440185546875,
#   1365.9801025390625,
#   1358.3863525390625,
#   1336.1884765625,
#   1315.9207763671875,
#   1342.7884521484375,
#   1330.53076171875,
#   1377.3197021484375,
#   1284.23583984375,
#   1282.8365478515625,
#   1264.13134765625,
#   1249.9769287109375,
#   1253.6749267578125,
#   1246.2744140625,
#   1219.8529052734375,
#   1193.77587890625,
#   1219.1221923828125,
#   1209.0989990234375,
#   1207.5400390625,
#   1159.94677734375,
#   1197.5814208984375,
#   1165.6087646484375,
#   1167.4384765625,
#   1159.5537109375,
#   1150.9609375,
#   1136.808349609375,
#   1130.03955078125,
#   1176.934814453125,
#   1172.5902099609375,
#   1175.018798828125,
#   1121.190185546875,
#   1116.2620849609375,
#   1091.3629150390625,
#   1071.9249267578125,
#   1087.7178955078125,
#   1073.258056640625,
#   1044.343017578125,
#   1020.9295043945312,
#   1029.7945556640625,
#   1023.8284912109375,
#   1011.659912109375,
#   990.7462768554688,
#   1006.4932861328125,
#   1009.2164916992188,
#   1020.2915649414062,
#   1026.644775390625,
#   1029.110107421875,
#   981.3128662109375,
#   964.1035766601562,
#   949.4906005859375,
#   942.908447265625,
#   949.5438842773438,
#   1023.1841430664062,
#   987.876708984375,
#   1028.0428466796875,
#   1008.9126586914062,
#   961.06103515625,
#   973.8096313476562,
#   976.5811767578125,
#   944.46533203125,
#   939.5007934570312,
#   921.7153930664062,
#   892.6040649414062,
#   925.3267822265625,
#   879.405517578125,
#   919.0703125,
#   874.6470336914062,
#   886.2477416992188,
#   1044.719970703125,
#   1205.6136474609375,
#   930.4920043945312,
#   904.1043701171875,
#   872.4489135742188,
#   858.27880859375,
#   877.092041015625,
#   855.371826171875,
#   854.8333740234375,
#   816.2012329101562,
#   802.8277587890625,
#   837.663330078125,
#   822.5448608398438,
#   816.670166015625,
#   804.1949462890625,
#   801.4645385742188,
#   784.072509765625,
#   782.8576049804688,
#   783.1286010742188,
#   815.173583984375,
#   801.04541015625,
#   790.2802124023438,
#   781.3050537109375,
#   763.9667358398438,
#   781.2927856445312,
#   800.1412353515625,
#   751.5448608398438,
#   759.0941162109375,
#   744.01708984375,
#   745.5589599609375,
#   739.03125,
#   767.2700805664062,
#   792.7744750976562,
#   860.3735961914062,
#   858.4886474609375,
#   842.27197265625,
#   802.7449951171875,
#   758.1261596679688,
#   722.48974609375,
#   743.0718994140625,
#   750.7686767578125,
#   705.5437622070312,
#   689.9168090820312,
#   670.4575805664062,
#   658.0527954101562,
#   655.9177856445312,
#   691.923095703125,
#   684.7605590820312,
#   677.82470703125,
#   680.6175537109375,
#   701.4274291992188,
#   685.31201171875,
#   670.5323486328125,
#   665.91259765625,
#   665.5906982421875,
#   687.509521484375,
#   702.79833984375,
#   685.035888671875,
#   661.27294921875,
#   639.1098022460938,
#   642.6625366210938,
#   625.78662109375,
#   633.4671020507812,
#   633.528564453125,
#   640.557861328125,
#   647.83935546875,
#   651.3715209960938,
#   693.9590454101562,
#   639.299072265625,
#   615.8628540039062,
#   608.37451171875,
#   651.3229370117188,
#   626.960205078125,
#   587.9325561523438,
#   573.6503295898438],
#  'mean_absolute_error': [117.51425170898438,
#   70.53292083740234,
#   63.265995025634766,
#   54.419830322265625,
#   48.42609405517578,
#   43.322418212890625,
#   40.865074157714844,
#   38.26765060424805,
#   36.82276916503906,
#   36.9416389465332,
#   35.097923278808594,
#   34.45853805541992,
#   33.69624328613281,
#   35.27961349487305,
#   33.6718635559082,
#   33.088645935058594,
#   32.86664962768555,
#   33.073402404785156,
#   33.38362121582031,
#   32.9591178894043,
#   32.79762268066406,
#   32.100547790527344,
#   31.702960968017578,
#   31.999998092651367,
#   31.617929458618164,
#   31.257610321044922,
#   31.22603988647461,
#   31.228273391723633,
#   30.95185089111328,
#   31.37957191467285,
#   30.929553985595703,
#   30.825620651245117,
#   31.674306869506836,
#   31.507261276245117,
#   30.477397918701172,
#   30.591529846191406,
#   30.618022918701172,
#   30.502025604248047,
#   30.03399085998535,
#   30.10479736328125,
#   30.300762176513672,
#   30.146211624145508,
#   29.799484252929688,
#   29.432214736938477,
#   29.588973999023438,
#   29.53186798095703,
#   29.139463424682617,
#   29.375198364257812,
#   29.621593475341797,
#   29.9969482421875,
#   29.513113021850586,
#   29.182783126831055,
#   28.78478240966797,
#   29.331106185913086,
#   28.9420108795166,
#   28.9622745513916,
#   28.573501586914062,
#   28.191059112548828,
#   28.73699378967285,
#   28.750673294067383,
#   29.40703773498535,
#   29.00494956970215,
#   28.807077407836914,
#   28.426801681518555,
#   28.837087631225586,
#   28.65540313720703,
#   27.829973220825195,
#   28.8043270111084,
#   29.103166580200195,
#   29.08501625061035,
#   27.54145050048828,
#   27.183971405029297,
#   27.144044876098633,
#   27.185592651367188,
#   27.063444137573242,
#   27.341947555541992,
#   26.575965881347656,
#   26.600553512573242,
#   26.408281326293945,
#   26.245637893676758,
#   26.164714813232422,
#   26.012807846069336,
#   26.616384506225586,
#   26.309650421142578,
#   26.0651912689209,
#   26.020170211791992,
#   25.63515853881836,
#   25.797046661376953,
#   25.42119598388672,
#   25.410093307495117,
#   25.298297882080078,
#   25.40583038330078,
#   25.40253257751465,
#   25.52362060546875,
#   25.674726486206055,
#   25.734289169311523,
#   25.136415481567383,
#   24.85515594482422,
#   25.011808395385742,
#   25.32154083251953,
#   25.287988662719727,
#   25.316295623779297,
#   24.861549377441406,
#   24.60992431640625,
#   24.486906051635742,
#   24.3308162689209,
#   24.536592483520508,
#   24.279491424560547,
#   24.19103240966797,
#   24.184921264648438,
#   23.909238815307617,
#   23.799406051635742,
#   23.989091873168945,
#   23.891016006469727,
#   24.260784149169922,
#   23.58685874938965,
#   23.570459365844727,
#   23.414709091186523,
#   23.312053680419922,
#   23.323427200317383,
#   23.260934829711914,
#   23.067026138305664,
#   22.815656661987305,
#   23.076398849487305,
#   22.981548309326172,
#   22.897846221923828,
#   22.56344985961914,
#   22.869983673095703,
#   22.563880920410156,
#   22.616178512573242,
#   22.54663848876953,
#   22.46320152282715,
#   22.371662139892578,
#   22.328428268432617,
#   22.683115005493164,
#   22.704124450683594,
#   22.70144271850586,
#   22.178882598876953,
#   22.254587173461914,
#   21.997386932373047,
#   21.836563110351562,
#   21.99138832092285,
#   21.83721160888672,
#   21.546340942382812,
#   21.2894344329834,
#   21.420682907104492,
#   21.37939453125,
#   21.221107482910156,
#   21.044456481933594,
#   21.229204177856445,
#   21.23074722290039,
#   21.402841567993164,
#   21.520545959472656,
#   21.430387496948242,
#   21.010282516479492,
#   20.827592849731445,
#   20.69717025756836,
#   20.625438690185547,
#   20.693178176879883,
#   21.469491958618164,
#   21.131093978881836,
#   21.529748916625977,
#   21.346778869628906,
#   20.837383270263672,
#   20.99541664123535,
#   20.99605941772461,
#   20.647602081298828,
#   20.668712615966797,
#   20.463146209716797,
#   20.175691604614258,
#   20.565757751464844,
#   20.020832061767578,
#   20.492677688598633,
#   19.967201232910156,
#   20.085464477539062,
#   21.826501846313477,
#   23.142662048339844,
#   20.609769821166992,
#   20.321718215942383,
#   19.944656372070312,
#   19.860013961791992,
#   20.06328773498535,
#   19.814390182495117,
#   19.813247680664062,
#   19.42738151550293,
#   19.207551956176758,
#   19.584360122680664,
#   19.467992782592773,
#   19.45027732849121,
#   19.259550094604492,
#   19.2498722076416,
#   19.029626846313477,
#   19.027524948120117,
#   19.092527389526367,
#   19.43850326538086,
#   19.24374008178711,
#   19.165157318115234,
#   19.0126953125,
#   18.83421516418457,
#   19.06615447998047,
#   19.274009704589844,
#   18.68657684326172,
#   18.72751235961914,
#   18.603919982910156,
#   18.643400192260742,
#   18.538000106811523,
#   18.848039627075195,
#   19.148527145385742,
#   19.94121742248535,
#   19.90447235107422,
#   19.776779174804688,
#   19.332578659057617,
#   18.78851890563965,
#   18.394168853759766,
#   18.6700439453125,
#   18.710575103759766,
#   18.166831970214844,
#   17.98615074157715,
#   17.713926315307617,
#   17.51195526123047,
#   17.5544490814209,
#   18.031177520751953,
#   17.876123428344727,
#   17.811243057250977,
#   17.900554656982422,
#   18.111623764038086,
#   17.95844268798828,
#   17.770187377929688,
#   17.698097229003906,
#   17.716360092163086,
#   18.01494026184082,
#   18.182090759277344,
#   17.982336044311523,
#   17.673927307128906,
#   17.41858673095703,
#   17.454694747924805,
#   17.2091007232666,
#   17.310382843017578,
#   17.32170295715332,
#   17.388744354248047,
#   17.513622283935547,
#   17.602535247802734,
#   18.1848087310791,
#   17.400239944458008,
#   17.19019889831543,
#   16.987794876098633,
#   17.60549545288086,
#   17.259002685546875,
#   16.699430465698242,
#   16.463346481323242]}

# %% [markdown]
# ### Monitor the training process to avoid overfitting of the model.
#
# - The neural network may learn the data so well that its learning goes into overfitting.
#
# - To prevent this, you should monitor the training process
#
# - The curve of validation should follow the curve of training otherwise you should stop the training with EarlyStop.
#
# - The parameters of the model (like number of levels, number of neurons per level, optimizer function etc..) are not optimized

# %%
plt.figure(figsize = (20, 4))
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.title('model MAE')
plt.ylabel('MAE ')
plt.xlabel('Number of epochs')
plt.legend(["MAE", "Loss"], loc ="upper right")
plt.show()

# %% [markdown]
# ### Show the first prediction

# %%
# the number of elements inside numpy array should be the same as n_steps_in
x_input = np.array([ 8,  3 , 7 , 4,  1,  5, 11,  8,  1,  7 , 1,  2, 4 , 1 ,12,  6,  6 , 4,  4 , 2 , 6 , 6 , 7,  6,
                     1,  7 , 7 , 5 , 3 , 9 , 2 , 8 , 3 , 3,  8 , 6 , 3 , 1,  4, 12,  2,  2, 7 , 4,  2 , 9 , 8, 12,
                     7 , 2 , 4 , 4 , 7 , 2 , 4 , 5 , 4 , 1,  6 ,11 , 8 , 3, 10, 10 ,10, 10,  3 , 6 , 4,  4,  4,  7,
                     5 , 6 ,11 , 3 , 1, 10,  6,  1,  6 , 6 , 5 , 1,  4 , 1 , 2 , 7, 13 , 8 , 7 , 7 ,17 , 3,  2 , 7,
                     2 , 2 ,10 , 1,  4,  4 , 3 , 3 , 7 ,10 , 2, 3 , 5 , 1 , 2, 13, 10 , 8,  3 , 6 , 6 ,13,  4, 13,
                     2 , 1 ,10 ,16 , 5,  7,  7, 13 , 8,  2,  6, 20,  2,  4 , 8 ,13 ,10 , 9 , 1,  2 , 4, 19, 16 , 6,
                     5 , 5, 6 ,12 , 7 ,12 ,18 , 7 , 2, 16 ,11 , 9,  8 ,13  ,6 ,16 ,12,  5, 12, 13,  4 ,13, 15, 15,
                     16 ,10, 10,  8 , 6  ,5  ,7 , 2, 17, 12,16, 12])

# %%
# transform and predict.
x_input = x_input.reshape((1, n_steps_in))
yhat = model.predict(x_input, verbose=2)
print(yhat[0])

#12 25 28  4 15  1  6 24  6  2  6 16  5  4  9 15  3  2 20 12 15  8  8  8  4 13  9 12 15 11
# Out:
# 1/1 - 0s
# [13.623101 12.278589 11.534099 15.552346 15.09316  15.910137 11.253327
#  18.928581 14.791898 15.21431  15.148912 13.838738 10.954141 11.312092
#  13.428771 11.186857 18.290537 18.310802 17.669674 12.879218 14.562765
#  15.820354 12.767557 20.731087 16.843094 15.589421 17.329185 12.392403
#  20.526594 21.600033]

# %%
# predict and compute error
expected = test_y
predicted = []
for i in range(len(test_X)):
    x_input = test_X[i].reshape((1, n_steps_in)) # + 1 per la nuova feature aggiunta
    yhat = model.predict(x_input, verbose=0)
  
    predicted.append(np.around(yhat[0], decimals=1))

# %%
difference = abs(expected - predicted)
print(type(difference))
print(difference.shape[0], difference.shape[1])

# comment line below to see all the boxplots for every number of steps from 1 to n_steps_out
#difference =  np.reshape(difference, difference.shape[0] * difference.shape[1])

plt.figure(figsize = (14, 9))
#plt.boxplot(one_cell['nr_people'].values, vert = False)
plt.boxplot(difference, vert= True);
plt.xticks( rotation='vertical')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# 313 30

# %% [markdown]
# ### Compute the forecasting Error

# %%
mean_error =  np.reshape(difference, difference.shape[0] * difference.shape[1])
print('Mean error', np.mean(mean_error))
plt.figure(figsize = (14,1))
plt.boxplot(mean_error, vert= False);
plt.show()
# Out:
# Mean error 203.29120345059803
