# %% [markdown]
# ### Perform Forecasts with a Multilayer Perceptron Neural Network.

# %%
import tensorflow 
print('Tensorflow Version : ', tensorflow.__version__)
# Out:
# Tensorflow Version :  2.5.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import metrics

# %%
# load the data 
pollution_data = pd.read_csv("dati/NO2.csv")
pollution_data
# Out:
#                  datetime  NO2 (Biossido di azoto)
# 0     2020-01-01 00:00:00                     16.0
# 1      2020-01-01 1:00:00                     26.0
# 2      2020-01-01 2:00:00                     25.0
# 3      2020-01-01 3:00:00                     24.0
# 4      2020-01-01 4:00:00                     32.0
# ...                   ...                      ...
# 6930  2020-10-15 20:00:00                     43.0
# 6931  2020-10-15 21:00:00                     37.0
# 6932  2020-10-15 22:00:00                     38.0
# 6933  2020-10-15 23:00:00                     33.0
# 6934  2020-10-16 00:00:00                     30.0
#
# [6935 rows x 2 columns]

# %% [markdown]
# ### Visualizing data

# %%
series = pollution_data["NO2 (Biossido di azoto)"].values

# %%
plt.figure(figsize = (20, 6))
plt.xlabel("Time")
plt.ylabel("Transactions")

plt.plot(series)
plt.show()

# %% [markdown]
# ### How to prepare the data for the neural network.
#
# <img src = "img/Multistep.png" alt="Girl in a jacket" width="600" height="800">

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
         # find the end of this pattern
         end_ix = i + n_steps_in
         out_end_ix = end_ix + n_steps_out
         # check if we are beyond the sequence
         if out_end_ix > len(sequence):
             break
         # gather input and output parts of the pattern
         seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
         X.append(seq_x)
         y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 24,24

# split into samples
X, y = split_sequence(series, n_steps_in, n_steps_out)
count = 0
for i in range(len(X)):
    print(series[i],X[i], y[i])
    count +=1
    if count>7: break
# Out:
# 16.0 [16. 26. 25. 24. 32. 21. 18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49.
#  54. 48. 32. 26. 31. 23.] [14. 12.  9. 11.  9.  9. 10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51.
#  56. 55. 42. 34. 32. 28.]
# 26.0 [26. 25. 24. 32. 21. 18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54.
#  48. 32. 26. 31. 23. 14.] [12.  9. 11.  9.  9. 10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56.
#  55. 42. 34. 32. 28. 20.]
# 25.0 [25. 24. 32. 21. 18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54. 48.
#  32. 26. 31. 23. 14. 12.] [ 9. 11.  9.  9. 10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56. 55.
#  42. 34. 32. 28. 20. 16.]
# 24.0 [24. 32. 21. 18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54. 48. 32.
#  26. 31. 23. 14. 12.  9.] [11.  9.  9. 10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56. 55. 42.
#  34. 32. 28. 20. 16. 12.]
# 32.0 [32. 21. 18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54. 48. 32. 26.
#  31. 23. 14. 12.  9. 11.] [ 9.  9. 10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56. 55. 42. 34.
#  32. 28. 20. 16. 12. 10.]
# 21.0 [21. 18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54. 48. 32. 26. 31.
#  23. 14. 12.  9. 11.  9.] [ 9. 10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56. 55. 42. 34. 32.
#  28. 20. 16. 12. 10. 11.]
# 18.0 [18. 26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54. 48. 32. 26. 31. 23.
#  14. 12.  9. 11.  9.  9.] [10. 14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56. 55. 42. 34. 32. 28.
#  20. 16. 12. 10. 11. 10.]
# 26.0 [26. 29. 29. 22. 23. 27. 24. 23. 28. 36. 49. 54. 48. 32. 26. 31. 23. 14.
#  12.  9. 11.  9.  9. 10.] [14. 15. 18. 18. 29. 31. 33. 35. 40. 46. 51. 56. 55. 42. 34. 32. 28. 20.
#  16. 12. 10. 11. 10. 14.]

# %%
print(X.shape)
print(y.shape)
# Out:
# (6888, 24)
# (6888, 24)

# %%
train_size = 800
test_size = 223

train_X, test_X = X[:train_size], X[train_size:] 
train_y, test_y = y[:train_size], y[train_size:]

# %%
# define model
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=n_steps_in)) 
model.add(Dense(250, activation='relu', input_dim=n_steps_in)) 
model.add(Dense(n_steps_out))

model.compile(optimizer='adam', loss='mse' , metrics=[metrics.mae])

# fit model
history = model.fit(train_X, train_y, batch_size=128, epochs=250, verbose=2)
# Out:
# Epoch 1/250
# 7/7 - 1s - loss: 730.3057 - mean_absolute_error: 22.2124
# Epoch 2/250
# 7/7 - 0s - loss: 270.9772 - mean_absolute_error: 13.1305
# Epoch 3/250
# 7/7 - 0s - loss: 207.5508 - mean_absolute_error: 11.6000
# Epoch 4/250
# 7/7 - 0s - loss: 177.3242 - mean_absolute_error: 10.6130
# Epoch 5/250
# 7/7 - 0s - loss: 167.9272 - mean_absolute_error: 10.2674
# Epoch 6/250
# 7/7 - 0s - loss: 160.3315 - mean_absolute_error: 10.0617
# Epoch 7/250
# 7/7 - 0s - loss: 154.4697 - mean_absolute_error: 9.7530
# Epoch 8/250
# 7/7 - 0s - loss: 150.5341 - mean_absolute_error: 9.6189
# Epoch 9/250
# 7/7 - 0s - loss: 147.6790 - mean_absolute_error: 9.5468
# Epoch 10/250
# 7/7 - 0s - loss: 146.2686 - mean_absolute_error: 9.4558
# Epoch 11/250
# 7/7 - 0s - loss: 143.7038 - mean_absolute_error: 9.3830
# Epoch 12/250
# 7/7 - 0s - loss: 142.9699 - mean_absolute_error: 9.3344
# Epoch 13/250
# 7/7 - 0s - loss: 140.9476 - mean_absolute_error: 9.2840
# Epoch 14/250
# 7/7 - 0s - loss: 139.9794 - mean_absolute_error: 9.2138
# Epoch 15/250
# 7/7 - 0s - loss: 139.5490 - mean_absolute_error: 9.1507
# Epoch 16/250
# 7/7 - 0s - loss: 141.1332 - mean_absolute_error: 9.3372
# Epoch 17/250
# 7/7 - 0s - loss: 138.0253 - mean_absolute_error: 9.1686
# Epoch 18/250
# 7/7 - 0s - loss: 137.2751 - mean_absolute_error: 9.1499
# Epoch 19/250
# 7/7 - 0s - loss: 136.8822 - mean_absolute_error: 9.1660
# Epoch 20/250
# 7/7 - 0s - loss: 134.9185 - mean_absolute_error: 9.0503
# Epoch 21/250
# 7/7 - 0s - loss: 134.0022 - mean_absolute_error: 8.9842
# Epoch 22/250
# 7/7 - 0s - loss: 132.7729 - mean_absolute_error: 8.9847
# Epoch 23/250
# 7/7 - 0s - loss: 133.6042 - mean_absolute_error: 8.9607
# Epoch 24/250
# 7/7 - 0s - loss: 131.7540 - mean_absolute_error: 8.9366
# Epoch 25/250
# 7/7 - 0s - loss: 131.3776 - mean_absolute_error: 8.8831
# Epoch 26/250
# 7/7 - 0s - loss: 133.6725 - mean_absolute_error: 9.0279
# Epoch 27/250
# 7/7 - 0s - loss: 131.9805 - mean_absolute_error: 8.8997
# Epoch 28/250
# 7/7 - 0s - loss: 130.2497 - mean_absolute_error: 8.8302
# Epoch 29/250
# 7/7 - 0s - loss: 129.1036 - mean_absolute_error: 8.8442
# Epoch 30/250
# 7/7 - 0s - loss: 129.1867 - mean_absolute_error: 8.8272
# Epoch 31/250
# 7/7 - 0s - loss: 127.5422 - mean_absolute_error: 8.7476
# Epoch 32/250
# 7/7 - 0s - loss: 127.2825 - mean_absolute_error: 8.7676
# Epoch 33/250
# 7/7 - 0s - loss: 125.7507 - mean_absolute_error: 8.6855
# Epoch 34/250
# 7/7 - 0s - loss: 125.9234 - mean_absolute_error: 8.7140
# Epoch 35/250
# 7/7 - 0s - loss: 125.5745 - mean_absolute_error: 8.6828
# Epoch 36/250
# 7/7 - 0s - loss: 125.5336 - mean_absolute_error: 8.6592
# Epoch 37/250
# 7/7 - 0s - loss: 124.0962 - mean_absolute_error: 8.6354
# Epoch 38/250
# 7/7 - 0s - loss: 124.6580 - mean_absolute_error: 8.6184
# Epoch 39/250
# 7/7 - 0s - loss: 123.8275 - mean_absolute_error: 8.6256
# Epoch 40/250
# 7/7 - 0s - loss: 127.3513 - mean_absolute_error: 8.8120
# Epoch 41/250
# 7/7 - 0s - loss: 124.8911 - mean_absolute_error: 8.6727
# Epoch 42/250
# 7/7 - 0s - loss: 125.0972 - mean_absolute_error: 8.7198
# Epoch 43/250
# 7/7 - 0s - loss: 122.2416 - mean_absolute_error: 8.5533
# Epoch 44/250
# 7/7 - 0s - loss: 121.1911 - mean_absolute_error: 8.4852
# Epoch 45/250
# 7/7 - 0s - loss: 120.6781 - mean_absolute_error: 8.4745
# Epoch 46/250
# 7/7 - 0s - loss: 120.7673 - mean_absolute_error: 8.4636
# Epoch 47/250
# 7/7 - 0s - loss: 119.9299 - mean_absolute_error: 8.4316
# Epoch 48/250
# 7/7 - 0s - loss: 119.6817 - mean_absolute_error: 8.4406
# Epoch 49/250
# 7/7 - 0s - loss: 121.0651 - mean_absolute_error: 8.5204
# Epoch 50/250
# 7/7 - 0s - loss: 120.4105 - mean_absolute_error: 8.5288
# Epoch 51/250
# 7/7 - 0s - loss: 118.3694 - mean_absolute_error: 8.4054
# Epoch 52/250
# 7/7 - 0s - loss: 120.8799 - mean_absolute_error: 8.5595
# Epoch 53/250
# 7/7 - 0s - loss: 117.9466 - mean_absolute_error: 8.3888
# Epoch 54/250
# 7/7 - 0s - loss: 117.3864 - mean_absolute_error: 8.3863
# Epoch 55/250
# 7/7 - 0s - loss: 116.1443 - mean_absolute_error: 8.3047
# Epoch 56/250
# 7/7 - 0s - loss: 115.2038 - mean_absolute_error: 8.2694
# Epoch 57/250
# 7/7 - 0s - loss: 115.2548 - mean_absolute_error: 8.3068
# Epoch 58/250
# 7/7 - 0s - loss: 117.6460 - mean_absolute_error: 8.3540
# Epoch 59/250
# 7/7 - 0s - loss: 115.6244 - mean_absolute_error: 8.3078
# Epoch 60/250
# 7/7 - 0s - loss: 114.1262 - mean_absolute_error: 8.2621
# Epoch 61/250
# 7/7 - 0s - loss: 115.3930 - mean_absolute_error: 8.3023
# Epoch 62/250
# 7/7 - 0s - loss: 113.2086 - mean_absolute_error: 8.2261
# Epoch 63/250
# 7/7 - 0s - loss: 111.8278 - mean_absolute_error: 8.1394
# Epoch 64/250
# 7/7 - 0s - loss: 112.4549 - mean_absolute_error: 8.2147
# Epoch 65/250
# 7/7 - 0s - loss: 111.3080 - mean_absolute_error: 8.1087
# Epoch 66/250
# 7/7 - 0s - loss: 111.1103 - mean_absolute_error: 8.1246
# Epoch 67/250
# 7/7 - 0s - loss: 110.3776 - mean_absolute_error: 8.0955
# Epoch 68/250
# 7/7 - 0s - loss: 108.8848 - mean_absolute_error: 8.0269
# Epoch 69/250
# 7/7 - 0s - loss: 108.7486 - mean_absolute_error: 8.0228
# Epoch 70/250
# 7/7 - 0s - loss: 108.3200 - mean_absolute_error: 8.0342
# Epoch 71/250
# 7/7 - 0s - loss: 109.0203 - mean_absolute_error: 8.0321
# Epoch 72/250
# 7/7 - 0s - loss: 108.3149 - mean_absolute_error: 8.0565
# Epoch 73/250
# 7/7 - 0s - loss: 106.1848 - mean_absolute_error: 7.9468
# Epoch 74/250
# 7/7 - 0s - loss: 106.0945 - mean_absolute_error: 7.9208
# Epoch 75/250
# 7/7 - 0s - loss: 104.8356 - mean_absolute_error: 7.8771
# Epoch 76/250
# 7/7 - 0s - loss: 105.7190 - mean_absolute_error: 7.9219
# Epoch 77/250
# 7/7 - 0s - loss: 105.7271 - mean_absolute_error: 7.9078
# Epoch 78/250
# 7/7 - 0s - loss: 104.7042 - mean_absolute_error: 7.8520
# Epoch 79/250
# 7/7 - 0s - loss: 104.4376 - mean_absolute_error: 7.8850
# Epoch 80/250
# 7/7 - 0s - loss: 104.0320 - mean_absolute_error: 7.8565
# Epoch 81/250
# 7/7 - 0s - loss: 103.0602 - mean_absolute_error: 7.8043
# Epoch 82/250
# 7/7 - 0s - loss: 102.6465 - mean_absolute_error: 7.8243
# Epoch 83/250
# 7/7 - 0s - loss: 106.4928 - mean_absolute_error: 7.9213
# Epoch 84/250
# 7/7 - 0s - loss: 105.5577 - mean_absolute_error: 7.9059
# Epoch 85/250
# 7/7 - 0s - loss: 102.0943 - mean_absolute_error: 7.7975
# Epoch 86/250
# 7/7 - 0s - loss: 100.8112 - mean_absolute_error: 7.7224
# Epoch 87/250
# 7/7 - 0s - loss: 100.5507 - mean_absolute_error: 7.7181
# Epoch 88/250
# 7/7 - 0s - loss: 100.7691 - mean_absolute_error: 7.7195
# Epoch 89/250
# 7/7 - 0s - loss: 98.5784 - mean_absolute_error: 7.6416
# Epoch 90/250
# 7/7 - 0s - loss: 99.2190 - mean_absolute_error: 7.6738
# Epoch 91/250
# 7/7 - 0s - loss: 97.1791 - mean_absolute_error: 7.5695
# Epoch 92/250
# 7/7 - 0s - loss: 98.0033 - mean_absolute_error: 7.6170
# Epoch 93/250
# 7/7 - 0s - loss: 97.3236 - mean_absolute_error: 7.5754
# Epoch 94/250
# 7/7 - 0s - loss: 96.8990 - mean_absolute_error: 7.5695
# Epoch 95/250
# 7/7 - 0s - loss: 97.0117 - mean_absolute_error: 7.6265
# Epoch 96/250
# 7/7 - 0s - loss: 100.9047 - mean_absolute_error: 7.7552
# Epoch 97/250
# 7/7 - 0s - loss: 97.8909 - mean_absolute_error: 7.6314
# Epoch 98/250
# 7/7 - 0s - loss: 94.6640 - mean_absolute_error: 7.4900
# Epoch 99/250
# 7/7 - 0s - loss: 93.9757 - mean_absolute_error: 7.4422
# Epoch 100/250
# 7/7 - 0s - loss: 93.2569 - mean_absolute_error: 7.4335
# Epoch 101/250
# 7/7 - 0s - loss: 93.6870 - mean_absolute_error: 7.4540
# Epoch 102/250
# 7/7 - 0s - loss: 92.1075 - mean_absolute_error: 7.3624
# Epoch 103/250
# 7/7 - 0s - loss: 93.6970 - mean_absolute_error: 7.4573
# Epoch 104/250
# 7/7 - 0s - loss: 91.5195 - mean_absolute_error: 7.3451
# Epoch 105/250
# 7/7 - 0s - loss: 91.0631 - mean_absolute_error: 7.3094
# Epoch 106/250
# 7/7 - 0s - loss: 90.5669 - mean_absolute_error: 7.2881
# Epoch 107/250
# 7/7 - 0s - loss: 90.8838 - mean_absolute_error: 7.2896
# Epoch 108/250
# 7/7 - 0s - loss: 95.0152 - mean_absolute_error: 7.5448
# Epoch 109/250
# 7/7 - 0s - loss: 91.2057 - mean_absolute_error: 7.3465
# Epoch 110/250
# 7/7 - 0s - loss: 91.3638 - mean_absolute_error: 7.3374
# Epoch 111/250
# 7/7 - 0s - loss: 91.2191 - mean_absolute_error: 7.3355
# Epoch 112/250
# 7/7 - 0s - loss: 90.2761 - mean_absolute_error: 7.3067
# Epoch 113/250
# 7/7 - 0s - loss: 88.6513 - mean_absolute_error: 7.2282
# Epoch 114/250
# 7/7 - 0s - loss: 88.8613 - mean_absolute_error: 7.2363
# Epoch 115/250
# 7/7 - 0s - loss: 91.8427 - mean_absolute_error: 7.3969
# Epoch 116/250
# 7/7 - 0s - loss: 87.3159 - mean_absolute_error: 7.1680
# Epoch 117/250
# 7/7 - 0s - loss: 85.3132 - mean_absolute_error: 7.0827
# Epoch 118/250
# 7/7 - 0s - loss: 91.6768 - mean_absolute_error: 7.3475
# Epoch 119/250
# 7/7 - 0s - loss: 87.0859 - mean_absolute_error: 7.1579
# Epoch 120/250
# 7/7 - 0s - loss: 86.1859 - mean_absolute_error: 7.1097
# Epoch 121/250
# 7/7 - 0s - loss: 90.6213 - mean_absolute_error: 7.3323
# Epoch 122/250
# 7/7 - 0s - loss: 87.3896 - mean_absolute_error: 7.1854
# Epoch 123/250
# 7/7 - 0s - loss: 88.9248 - mean_absolute_error: 7.2827
# Epoch 124/250
# 7/7 - 0s - loss: 86.4276 - mean_absolute_error: 7.1157
# Epoch 125/250
# 7/7 - 0s - loss: 81.8210 - mean_absolute_error: 6.9308
# Epoch 126/250
# 7/7 - 0s - loss: 82.8750 - mean_absolute_error: 6.9681
# Epoch 127/250
# 7/7 - 0s - loss: 81.2513 - mean_absolute_error: 6.8958
# Epoch 128/250
# 7/7 - 0s - loss: 81.5015 - mean_absolute_error: 6.9139
# Epoch 129/250
# 7/7 - 0s - loss: 82.8952 - mean_absolute_error: 6.9849
# Epoch 130/250
# 7/7 - 0s - loss: 79.4981 - mean_absolute_error: 6.8393
# Epoch 131/250
# 7/7 - 0s - loss: 80.4978 - mean_absolute_error: 6.8512
# Epoch 132/250
# 7/7 - 0s - loss: 79.9571 - mean_absolute_error: 6.8215
# Epoch 133/250
# 7/7 - 0s - loss: 77.3208 - mean_absolute_error: 6.7084
# Epoch 134/250
# 7/7 - 0s - loss: 78.4910 - mean_absolute_error: 6.7426
# Epoch 135/250
# 7/7 - 0s - loss: 76.5241 - mean_absolute_error: 6.6853
# Epoch 136/250
# 7/7 - 0s - loss: 78.6424 - mean_absolute_error: 6.7927
# Epoch 137/250
# 7/7 - 0s - loss: 78.0168 - mean_absolute_error: 6.7691
# Epoch 138/250
# 7/7 - 0s - loss: 76.2981 - mean_absolute_error: 6.6997
# Epoch 139/250
# 7/7 - 0s - loss: 76.2914 - mean_absolute_error: 6.6807
# Epoch 140/250
# 7/7 - 0s - loss: 76.1970 - mean_absolute_error: 6.6519
# Epoch 141/250
# 7/7 - 0s - loss: 77.3316 - mean_absolute_error: 6.7643
# Epoch 142/250
# 7/7 - 0s - loss: 75.5561 - mean_absolute_error: 6.6539
# Epoch 143/250
# 7/7 - 0s - loss: 75.7700 - mean_absolute_error: 6.6613
# Epoch 144/250
# 7/7 - 0s - loss: 77.7550 - mean_absolute_error: 6.7662
# Epoch 145/250
# 7/7 - 0s - loss: 74.9542 - mean_absolute_error: 6.6192
# Epoch 146/250
# 7/7 - 0s - loss: 73.0294 - mean_absolute_error: 6.5113
# Epoch 147/250
# 7/7 - 0s - loss: 72.1135 - mean_absolute_error: 6.4606
# Epoch 148/250
# 7/7 - 0s - loss: 70.6734 - mean_absolute_error: 6.4325
# Epoch 149/250
# 7/7 - 0s - loss: 70.2080 - mean_absolute_error: 6.4022
# Epoch 150/250
# 7/7 - 0s - loss: 70.6250 - mean_absolute_error: 6.3977
# Epoch 151/250
# 7/7 - 0s - loss: 68.4121 - mean_absolute_error: 6.2908
# Epoch 152/250
# 7/7 - 0s - loss: 69.3586 - mean_absolute_error: 6.3581
# Epoch 153/250
# 7/7 - 0s - loss: 69.1740 - mean_absolute_error: 6.3478
# Epoch 154/250
# 7/7 - 0s - loss: 69.8337 - mean_absolute_error: 6.3747
# Epoch 155/250
# 7/7 - 0s - loss: 69.9549 - mean_absolute_error: 6.3726
# Epoch 156/250
# 7/7 - 0s - loss: 71.4706 - mean_absolute_error: 6.4585
# Epoch 157/250
# 7/7 - 0s - loss: 70.1487 - mean_absolute_error: 6.4179
# Epoch 158/250
# 7/7 - 0s - loss: 69.3226 - mean_absolute_error: 6.3481
# Epoch 159/250
# 7/7 - 0s - loss: 67.8287 - mean_absolute_error: 6.2757
# Epoch 160/250
# 7/7 - 0s - loss: 69.0583 - mean_absolute_error: 6.3365
# Epoch 161/250
# 7/7 - 0s - loss: 68.2213 - mean_absolute_error: 6.3223
# Epoch 162/250
# 7/7 - 0s - loss: 67.4329 - mean_absolute_error: 6.2723
# Epoch 163/250
# 7/7 - 0s - loss: 68.0689 - mean_absolute_error: 6.2783
# Epoch 164/250
# 7/7 - 0s - loss: 66.3059 - mean_absolute_error: 6.2063
# Epoch 165/250
# 7/7 - 0s - loss: 63.7439 - mean_absolute_error: 6.0709
# Epoch 166/250
# 7/7 - 0s - loss: 63.9514 - mean_absolute_error: 6.0824
# Epoch 167/250
# 7/7 - 0s - loss: 63.6992 - mean_absolute_error: 6.0721
# Epoch 168/250
# 7/7 - 0s - loss: 65.7133 - mean_absolute_error: 6.1733
# Epoch 169/250
# 7/7 - 0s - loss: 63.0924 - mean_absolute_error: 6.0472
# Epoch 170/250
# 7/7 - 0s - loss: 64.0334 - mean_absolute_error: 6.0856
# Epoch 171/250
# 7/7 - 0s - loss: 66.9664 - mean_absolute_error: 6.2359
# Epoch 172/250
# 7/7 - 0s - loss: 63.2859 - mean_absolute_error: 6.0451
# Epoch 173/250
# 7/7 - 0s - loss: 62.2750 - mean_absolute_error: 6.0000
# Epoch 174/250
# 7/7 - 0s - loss: 61.3553 - mean_absolute_error: 5.9740
# Epoch 175/250
# 7/7 - 0s - loss: 60.8363 - mean_absolute_error: 5.9041
# Epoch 176/250
# 7/7 - 0s - loss: 60.0968 - mean_absolute_error: 5.8780
# Epoch 177/250
# 7/7 - 0s - loss: 59.8362 - mean_absolute_error: 5.8565
# Epoch 178/250
# 7/7 - 0s - loss: 60.1713 - mean_absolute_error: 5.8922
# Epoch 179/250
# 7/7 - 0s - loss: 62.6103 - mean_absolute_error: 6.0268
# Epoch 180/250
# 7/7 - 0s - loss: 61.1125 - mean_absolute_error: 5.9131
# Epoch 181/250
# 7/7 - 0s - loss: 63.8013 - mean_absolute_error: 6.1022
# Epoch 182/250
# 7/7 - 0s - loss: 60.3683 - mean_absolute_error: 5.9267
# Epoch 183/250
# 7/7 - 0s - loss: 59.7031 - mean_absolute_error: 5.8730
# Epoch 184/250
# 7/7 - 0s - loss: 65.3883 - mean_absolute_error: 6.2197
# Epoch 185/250
# 7/7 - 0s - loss: 63.4896 - mean_absolute_error: 6.0964
# Epoch 186/250
# 7/7 - 0s - loss: 65.1499 - mean_absolute_error: 6.1755
# Epoch 187/250
# 7/7 - 0s - loss: 59.8565 - mean_absolute_error: 5.8798
# Epoch 188/250
# 7/7 - 0s - loss: 63.5832 - mean_absolute_error: 6.0655
# Epoch 189/250
# 7/7 - 0s - loss: 60.1071 - mean_absolute_error: 5.9197
# Epoch 190/250
# 7/7 - 0s - loss: 59.9986 - mean_absolute_error: 5.8932
# Epoch 191/250
# 7/7 - 0s - loss: 63.7041 - mean_absolute_error: 6.0824
# Epoch 192/250
# 7/7 - 0s - loss: 58.7752 - mean_absolute_error: 5.8519
# Epoch 193/250
# 7/7 - 0s - loss: 57.1737 - mean_absolute_error: 5.7621
# Epoch 194/250
# 7/7 - 0s - loss: 57.2393 - mean_absolute_error: 5.7421
# Epoch 195/250
# 7/7 - 0s - loss: 57.7847 - mean_absolute_error: 5.7935
# Epoch 196/250
# 7/7 - 0s - loss: 57.3960 - mean_absolute_error: 5.7377
# Epoch 197/250
# 7/7 - 0s - loss: 55.6763 - mean_absolute_error: 5.6497
# Epoch 198/250
# 7/7 - 0s - loss: 54.6749 - mean_absolute_error: 5.5999
# Epoch 199/250
# 7/7 - 0s - loss: 55.5887 - mean_absolute_error: 5.6613
# Epoch 200/250
# 7/7 - 0s - loss: 55.6776 - mean_absolute_error: 5.6665
# Epoch 201/250
# 7/7 - 0s - loss: 56.4714 - mean_absolute_error: 5.7245
# Epoch 202/250
# 7/7 - 0s - loss: 55.8574 - mean_absolute_error: 5.6842
# Epoch 203/250
# 7/7 - 0s - loss: 55.2102 - mean_absolute_error: 5.6511
# Epoch 204/250
# 7/7 - 0s - loss: 56.1492 - mean_absolute_error: 5.6858
# Epoch 205/250
# 7/7 - 0s - loss: 54.2886 - mean_absolute_error: 5.6030
# Epoch 206/250
# 7/7 - 0s - loss: 51.8187 - mean_absolute_error: 5.4279
# Epoch 207/250
# 7/7 - 0s - loss: 53.2965 - mean_absolute_error: 5.5343
# Epoch 208/250
# 7/7 - 0s - loss: 54.3098 - mean_absolute_error: 5.6188
# Epoch 209/250
# 7/7 - 0s - loss: 52.5093 - mean_absolute_error: 5.4800
# Epoch 210/250
# 7/7 - 0s - loss: 57.2324 - mean_absolute_error: 5.7703
# Epoch 211/250
# 7/7 - 0s - loss: 54.0301 - mean_absolute_error: 5.5666
# Epoch 212/250
# 7/7 - 0s - loss: 52.5159 - mean_absolute_error: 5.4760
# Epoch 213/250
# 7/7 - 0s - loss: 57.8136 - mean_absolute_error: 5.7943
# Epoch 214/250
# 7/7 - 0s - loss: 53.9902 - mean_absolute_error: 5.5775
# Epoch 215/250
# 7/7 - 0s - loss: 53.1657 - mean_absolute_error: 5.5029
# Epoch 216/250
# 7/7 - 0s - loss: 52.4079 - mean_absolute_error: 5.4915
# Epoch 217/250
# 7/7 - 0s - loss: 51.9353 - mean_absolute_error: 5.4643
# Epoch 218/250
# 7/7 - 0s - loss: 51.6790 - mean_absolute_error: 5.4373
# Epoch 219/250
# 7/7 - 0s - loss: 51.6215 - mean_absolute_error: 5.4427
# Epoch 220/250
# 7/7 - 0s - loss: 51.4161 - mean_absolute_error: 5.4077
# Epoch 221/250
# 7/7 - 0s - loss: 52.2169 - mean_absolute_error: 5.4922
# Epoch 222/250
# 7/7 - 0s - loss: 49.7027 - mean_absolute_error: 5.3315
# Epoch 223/250
# 7/7 - 0s - loss: 49.0678 - mean_absolute_error: 5.2897
# Epoch 224/250
# 7/7 - 0s - loss: 48.4871 - mean_absolute_error: 5.2575
# Epoch 225/250
# 7/7 - 0s - loss: 49.7279 - mean_absolute_error: 5.3332
# Epoch 226/250
# 7/7 - 0s - loss: 51.0291 - mean_absolute_error: 5.4159
# Epoch 227/250
# 7/7 - 0s - loss: 53.4921 - mean_absolute_error: 5.5737
# Epoch 228/250
# 7/7 - 0s - loss: 50.1699 - mean_absolute_error: 5.3731
# Epoch 229/250
# 7/7 - 0s - loss: 52.1228 - mean_absolute_error: 5.5169
# Epoch 230/250
# 7/7 - 0s - loss: 49.7182 - mean_absolute_error: 5.3124
# Epoch 231/250
# 7/7 - 0s - loss: 58.9879 - mean_absolute_error: 5.8670
# Epoch 232/250
# 7/7 - 0s - loss: 54.3330 - mean_absolute_error: 5.6208
# Epoch 233/250
# 7/7 - 0s - loss: 51.0211 - mean_absolute_error: 5.4281
# Epoch 234/250
# 7/7 - 0s - loss: 50.2033 - mean_absolute_error: 5.3628
# Epoch 235/250
# 7/7 - 0s - loss: 48.4223 - mean_absolute_error: 5.2495
# Epoch 236/250
# 7/7 - 0s - loss: 47.4446 - mean_absolute_error: 5.2096
# Epoch 237/250
# 7/7 - 0s - loss: 48.1418 - mean_absolute_error: 5.2397
# Epoch 238/250
# 7/7 - 0s - loss: 48.5338 - mean_absolute_error: 5.2426
# Epoch 239/250
# 7/7 - 0s - loss: 49.3600 - mean_absolute_error: 5.3200
# Epoch 240/250
# 7/7 - 0s - loss: 47.4988 - mean_absolute_error: 5.2110
# Epoch 241/250
# 7/7 - 0s - loss: 46.3050 - mean_absolute_error: 5.1392
# Epoch 242/250
# 7/7 - 0s - loss: 46.1024 - mean_absolute_error: 5.1315
# Epoch 243/250
# 7/7 - 0s - loss: 48.0617 - mean_absolute_error: 5.2135
# Epoch 244/250
# 7/7 - 0s - loss: 45.7598 - mean_absolute_error: 5.1025
# Epoch 245/250
# 7/7 - 0s - loss: 45.3290 - mean_absolute_error: 5.0686
# Epoch 246/250
# 7/7 - 0s - loss: 47.8666 - mean_absolute_error: 5.2698
# Epoch 247/250
# 7/7 - 0s - loss: 46.7950 - mean_absolute_error: 5.1437
# Epoch 248/250
# 7/7 - 0s - loss: 46.4131 - mean_absolute_error: 5.1344
# Epoch 249/250
# 7/7 - 0s - loss: 46.1716 - mean_absolute_error: 5.1317
# Epoch 250/250
# 7/7 - 0s - loss: 44.3210 - mean_absolute_error: 5.0125

# %%
history.history
# Out:
# {'loss': [730.3057250976562,
#   270.97723388671875,
#   207.5508270263672,
#   177.32415771484375,
#   167.92718505859375,
#   160.33148193359375,
#   154.4696502685547,
#   150.5340576171875,
#   147.67898559570312,
#   146.26864624023438,
#   143.70375061035156,
#   142.96986389160156,
#   140.94760131835938,
#   139.9794464111328,
#   139.5489501953125,
#   141.13316345214844,
#   138.02532958984375,
#   137.2751007080078,
#   136.88223266601562,
#   134.91848754882812,
#   134.00222778320312,
#   132.7729034423828,
#   133.60415649414062,
#   131.75404357910156,
#   131.3775634765625,
#   133.67247009277344,
#   131.98049926757812,
#   130.2497100830078,
#   129.1035919189453,
#   129.1867218017578,
#   127.54219055175781,
#   127.28251647949219,
#   5.502925872802734,
#   5.491540431976318,
#   5.464298725128174,
#   5.437329292297363,
#   5.442735195159912,
#   5.407734394073486,
#   5.492176055908203,
#   5.331500053405762,
#   5.289746284484863,
#   5.257451057434082,
#   5.333154678344727,
#   5.4159369468688965,
#   5.573653697967529,
#   5.37312126159668,
#   5.516897201538086,
#   5.312437534332275,
#   5.867018222808838,
#   5.620809555053711,
#   5.428140163421631,
#   5.3627610206604,
#   5.249494552612305,
#   5.20963191986084,
#   5.239654064178467,
#   5.242631912231445,
#   5.319981575012207,
#   5.210992336273193,
#   5.1392083168029785,
#   5.131462574005127,
#   5.213526725769043,
#   5.102461338043213,
#   5.068558216094971,
#   5.269819736480713,
#   5.143659591674805,
#   5.134374618530273,
#   5.131707668304443,
#   5.012545585632324]}

# %% [markdown]
# ### Monitor the training process to avoid overfitting of the model.
#
# - The neural network may learn the data so well that its learning goes into overfitting.
#
# - To prevent this, you should monitor the training process
#
# - The curve of validation should follow the curve of training otherwise you should stop the training with EarlyStop.
#
# - The parameters of the model (like number of levels, number of neurons per level, optimizer function etc..) are not optimized

# %%
plt.figure(figsize = (20, 4))
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.title('model MAE')
plt.ylabel('MAE ')
plt.xlabel('Number of epochs')
plt.legend(["MAE", "Loss"], loc ="upper right")
plt.show()

# %% [markdown]
# ### Show the first prediction

# %%
# the number of elements inside numpy array should be the same as n_steps_in
x_input = np.array([ 16., 26. ,25., 24., 32. ,21., 18., 26., 29., 29., 22. ,23. ,27., 24. ,23., 28. ,36., 49.,
 54., 48., 32. ,26., 31., 23.])

# %%
# transform and predict.
x_input = x_input.reshape((1, n_steps_in))
yhat = model.predict(x_input, verbose=2)
print(yhat[0])

#12 25 28  4 15  1  6 24  6  2  6 16  5  4  9 15  3  2 20 12 15  8  8  8  4 13  9 12 15 11
# Out:
# 1/1 - 0s
# [18.176888  18.133627  17.681818  14.856228  15.2927475 14.29993
#  16.920464  19.727108  21.987883  25.5815    26.649721  28.209595
#  30.232014  30.277027  30.667294  35.884396  43.707752  53.602474
#  57.269054  50.18651   42.26852   38.148853  35.11407   32.121384 ]

# %%
# predict and compute error
expected = test_y
predicted = []
for i in range(len(test_X)):
    x_input = test_X[i].reshape((1, n_steps_in)) # + 1 per la nuova feature aggiunta
    yhat = model.predict(x_input, verbose=0)
  
    predicted.append(np.around(yhat[0], decimals=1))

# %%
difference = abs(expected - predicted)
print(type(difference))
print(difference.shape[0], difference.shape[1])

# comment line below to see all the boxplots for every number of steps from 1 to n_steps_out
#difference =  np.reshape(difference, difference.shape[0] * difference.shape[1])

plt.figure(figsize = (14, 9))
#plt.boxplot(one_cell['nr_people'].values, vert = False)
plt.boxplot(difference, vert= True);
plt.xticks( rotation='vertical')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# 6088 24

# %% [markdown]
# ### Compute the forecasting Error

# %%
mean_error =  np.reshape(difference, difference.shape[0] * difference.shape[1])
print('Mean error', np.mean(mean_error))
plt.figure(figsize = (14,1))
plt.boxplot(mean_error, vert= False);
plt.show()
# Out:
# Mean error 9.653257773138318
