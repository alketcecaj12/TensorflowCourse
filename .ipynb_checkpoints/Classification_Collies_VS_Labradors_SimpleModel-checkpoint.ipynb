# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import os
import zipfile
from tensorflow.keras.utils import plot_model

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        'C:/Users/alket/TensorflowImages/labrador-bordercollie/',  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 150x150
        batch_size=64,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 104 images belonging to 2 classes.

# %%
model = models.Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(2))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_generator, epochs=30, 
                    validation_data=(train_generator))
# Out:
# Epoch 1/30
# 2/2 [==============================] - 7s 3s/step - loss: 5.8575 - accuracy: 0.4712 - val_loss: 6.3911 - val_accuracy: 0.5000
# Epoch 2/30
# 2/2 [==============================] - 6s 3s/step - loss: 5.2922 - accuracy: 0.5000 - val_loss: 0.8548 - val_accuracy: 0.5000
# Epoch 3/30
# 2/2 [==============================] - 7s 4s/step - loss: 0.7530 - accuracy: 0.5865 - val_loss: 0.5499 - val_accuracy: 0.8365
# Epoch 4/30
# 2/2 [==============================] - 7s 3s/step - loss: 0.6575 - accuracy: 0.7115 - val_loss: 0.4739 - val_accuracy: 0.9327
# Epoch 5/30
# 2/2 [==============================] - 7s 4s/step - loss: 0.4514 - accuracy: 0.9038 - val_loss: 0.3374 - val_accuracy: 0.9712
# Epoch 6/30
# 2/2 [==============================] - 8s 5s/step - loss: 0.3142 - accuracy: 0.9327 - val_loss: 0.3743 - val_accuracy: 0.7788
# Epoch 7/30
# 2/2 [==============================] - 6s 4s/step - loss: 0.3794 - accuracy: 0.7788 - val_loss: 0.1804 - val_accuracy: 0.9712
# Epoch 8/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.1509 - accuracy: 0.9808 - val_loss: 0.1973 - val_accuracy: 0.9423
# Epoch 9/30
# 2/2 [==============================] - 6s 4s/step - loss: 0.1596 - accuracy: 0.9615 - val_loss: 0.1034 - val_accuracy: 0.9808
# Epoch 10/30
# 2/2 [==============================] - 7s 3s/step - loss: 0.0909 - accuracy: 0.9808 - val_loss: 0.0487 - val_accuracy: 0.9904
# Epoch 11/30
# 2/2 [==============================] - 6s 4s/step - loss: 0.0520 - accuracy: 0.9904 - val_loss: 0.0406 - val_accuracy: 1.0000
# Epoch 12/30
# 2/2 [==============================] - 7s 3s/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 13/30
# 2/2 [==============================] - 6s 4s/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 14/30
# 2/2 [==============================] - 7s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 15/30
# 2/2 [==============================] - 7s 3s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 16/30
# 2/2 [==============================] - 6s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 17/30
# 2/2 [==============================] - 7s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 18/30
# 2/2 [==============================] - 7s 4s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 6.8689e-04 - val_accuracy: 1.0000
# Epoch 19/30
# 2/2 [==============================] - 7s 4s/step - loss: 6.6085e-04 - accuracy: 1.0000 - val_loss: 5.6673e-04 - val_accuracy: 1.0000
# Epoch 20/30
# 2/2 [==============================] - 7s 5s/step - loss: 6.2446e-04 - accuracy: 1.0000 - val_loss: 6.8646e-04 - val_accuracy: 1.0000
# Epoch 21/30
# 2/2 [==============================] - 6s 4s/step - loss: 6.9670e-04 - accuracy: 1.0000 - val_loss: 6.1429e-04 - val_accuracy: 1.0000
# Epoch 22/30
# 2/2 [==============================] - 7s 5s/step - loss: 5.4116e-04 - accuracy: 1.0000 - val_loss: 3.8931e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 2/2 [==============================] - 7s 4s/step - loss: 3.4808e-04 - accuracy: 1.0000 - val_loss: 1.9875e-04 - val_accuracy: 1.0000
# Epoch 24/30
# 2/2 [==============================] - 8s 4s/step - loss: 1.8160e-04 - accuracy: 1.0000 - val_loss: 1.2322e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 2/2 [==============================] - 8s 5s/step - loss: 1.6281e-04 - accuracy: 1.0000 - val_loss: 1.6751e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 2/2 [==============================] - 9s 4s/step - loss: 1.5583e-04 - accuracy: 1.0000 - val_loss: 1.1776e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 2/2 [==============================] - 9s 4s/step - loss: 1.1079e-04 - accuracy: 1.0000 - val_loss: 9.6554e-05 - val_accuracy: 1.0000
# Epoch 28/30
# 2/2 [==============================] - 8s 4s/step - loss: 9.4045e-05 - accuracy: 1.0000 - val_loss: 8.4602e-05 - val_accuracy: 1.0000
# Epoch 29/30
# 2/2 [==============================] - 8s 4s/step - loss: 8.1999e-05 - accuracy: 1.0000 - val_loss: 7.3546e-05 - val_accuracy: 1.0000
# Epoch 30/30
# 2/2 [==============================] - 8s 6s/step - loss: 7.0864e-05 - accuracy: 1.0000 - val_loss: 6.4517e-05 - val_accuracy: 1.0000

# %%
plt.figure(figsize= (20, 5))
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(train_generator, verbose=2)
# Out:
# 2/2 - 2s - loss: 6.4517e-05 - accuracy: 1.0000

# %%
print(test_acc)
# Out:
# 1.0

# %%
plot_model(model, to_file = "network.png", show_shapes=True) #rankdir='LR')
