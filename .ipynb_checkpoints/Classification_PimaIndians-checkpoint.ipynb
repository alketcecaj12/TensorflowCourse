# %%
import numpy as np
import tensorflow as tf 
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.utils import plot_model

# %%
data = pd.read_csv('dati/diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
X, y = data[['Glucose', 'BMI', 'Age']].astype(float), data.iloc[:,-1]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
y.shape
# Out:
# (768,)

# %%
# create model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1500, input_dim=3, activation='relu'))
model.add(tf.keras.layers.Dense(1000, input_dim=3, activation='relu'))
model.add(tf.keras.layers.Dense(500, input_dim=2, activation='relu'))
model.add(tf.keras.layers.Dense(100, input_dim=1, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
# Compile model

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs = 500, batch_size = 64)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 23ms/step - loss: 2.7296 - accuracy: 0.5547
# Epoch 2/500
# 12/12 [==============================] - 0s 21ms/step - loss: 1.1698 - accuracy: 0.5586
# Epoch 3/500
# 12/12 [==============================] - 0s 21ms/step - loss: 0.7687 - accuracy: 0.5417
# Epoch 4/500
# 12/12 [==============================] - 0s 19ms/step - loss: 0.6908 - accuracy: 0.5977
# Epoch 5/500
# 12/12 [==============================] - 0s 21ms/step - loss: 0.6734 - accuracy: 0.6315
# Epoch 6/500
# 12/12 [==============================] - 0s 22ms/step - loss: 0.6769 - accuracy: 0.5768
# Epoch 7/500
# 12/12 [==============================] - 0s 22ms/step - loss: 0.6745 - accuracy: 0.6094
# Epoch 8/500
# 12/12 [==============================] - 0s 20ms/step - loss: 0.6808 - accuracy: 0.6133
# Epoch 9/500
# 12/12 [==============================] - 0s 19ms/step - loss: 0.6433 - accuracy: 0.6419
# Epoch 10/500
# ...

# %%
history.history
# Out:
# {'loss': [2.7295868396759033,
#   1.1698378324508667,
#   0.7687069773674011,
#   0.6907637119293213,
#   0.67344731092453,
#   0.6768733859062195,
#   0.6744579672813416,
#   0.6808075904846191,
#   0.6433400511741638,
#   0.6650329232215881,
#   0.6963184475898743,
#   0.6755974888801575,
#   0.6670846939086914,
#   0.6536893248558044,
#   0.6364242434501648,
#   0.632841169834137,
#   0.6392272710800171,
#   0.6256570816040039,
#   0.6305498480796814,
#   0.6343207359313965,
#   0.6267966628074646,
#   0.6303738951683044,
#   0.6309781670570374,
#   0.6210370659828186,
#   0.6167029738426208,
#   0.6276125311851501,
#   0.6152829527854919,
#   0.6047758460044861,
#   0.6107715964317322,
#   0.6101561188697815,
#   0.6213314533233643,
#   0.6105453372001648,
#   0.626850426197052,
#   0.6060440540313721,
#   0.6048902273178101,
#   0.6170132756233215,
#   0.6263865232467651,
#   0.6040418744087219,
#   0.6381796002388,
#   0.6067979335784912,
#   0.6084657311439514,
# ...

# %%
plt.figure(figsize = (20, 4))
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.legend([ 'loss', 'accuracy'], loc = 'upper right')

plt.show()

# %%
model.predict([[ 87. ,    26. , 31.0]])
# Out:
# array([[0.02058548]], dtype=float32)

# %%
import visualkeras

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=407x27 at 0x15BF32CEAC0>
