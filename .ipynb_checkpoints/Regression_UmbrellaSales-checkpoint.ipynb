# %%
import numpy as np
import tensorflow as tf 
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.utils import plot_model

# %%
data = pd.read_csv('dati/vendite_ombrelli.csv')
data
# Out:
#      pioggia_mm  ombrelli
# 0          21.5       236
# 1          25.2       340
# 2           5.1       135
# 3          17.4       305
# 4          18.4       220
# ..          ...       ...
# 495        21.2       246
# 496        11.5       133
# 497        18.1       306
# 498        12.2       231
# 499        15.4        20
#
# [500 rows x 2 columns]

# %%
plt.scatter(data['pioggia_mm'], data['ombrelli'])
plt.show()

# %%
mm_pioggia = data['pioggia_mm'].values
nr_omb = data['ombrelli'].values

# %%
X_train, X_test = mm_pioggia[0:400], mm_pioggia[400:]
y_train, y_test = nr_omb[0:400], nr_omb[400:]

# %%
# Instantiate a Sequential model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(500, input_shape=(1,),activation='relu'))
model.add(tf.keras.layers.Dense(100, input_shape=(1,),activation='relu'))
model.add(tf.keras.layers.Dense(50, input_shape=(1,),activation='relu'))
model.add(tf.keras.layers.Dense(1))

# %%
# Compile your model
model.compile(optimizer = 'adam', loss = 'mse')

# Fit your model on your data for 30 epochs
history = model.fit(X_train, y_train, epochs = 500)
# Out:
# Epoch 1/500
# 13/13 [==============================] - 0s 2ms/step - loss: 60209.1055
# Epoch 2/500
# 13/13 [==============================] - 0s 2ms/step - loss: 52625.2031
# Epoch 3/500
# 13/13 [==============================] - 0s 2ms/step - loss: 36013.1562
# Epoch 4/500
# 13/13 [==============================] - 0s 2ms/step - loss: 12190.7158
# Epoch 5/500
# 13/13 [==============================] - 0s 2ms/step - loss: 3922.1819
# Epoch 6/500
# 13/13 [==============================] - 0s 2ms/step - loss: 3257.6641
# Epoch 7/500
# 13/13 [==============================] - 0s 2ms/step - loss: 3205.8940
# Epoch 8/500
# 13/13 [==============================] - 0s 2ms/step - loss: 3038.2078
# Epoch 9/500
# 13/13 [==============================] - 0s 2ms/step - loss: 2976.7175
# Epoch 10/500
# 13/13 [==============================] - 0s 2ms/step - loss: 2986.4543
# Epoch 11/500
# 13/13 [==============================] - 0s 2ms/step - loss: 3024.8079
# Epoch 12/500
# ...

# %%
plt.figure(figsize = (20, 5))
plt.plot(history.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss function')
plt.show()

# %%
model.predict([37.3])
# Out:
# array([[474.16507]], dtype=float32)

# %%
previsioni = []
for i in X_test: 
    yhat = model.predict([i])
    print(yhat[0][0])
    previsioni.append(yhat[0][0])
# Out:
# 259.21725
# 110.59803
# 223.96347
# 113.97726
# 330.8621
# 216.00293
# 308.1177
# 243.29617
# 239.88452
# 224.41833
# 165.0555
# 330.8621
# 167.55737
# 183.02357
# 229.64954
# 194.39575
# 194.39575
# 179.61191
# 269.4522
# 192.12129
# 303.5688
# 139.88467
# 320.62708
# 299.01993
# 329.72485
# 310.3921
# 134.25264
# 124.11494
# 275.1383
# 150.0442
# 150.0442
# 219.41458
# 264.90332
# 271.72665
# 308.1177
# 321.76428
# 317.2154
# 327.45038
# 223.96347
# 225.10068
# 251.25674
# 239.88452
# 159.14197
# 296.74548
# 227.3751
# 287.64777
# 147.76978
# 213.72847
# 247.84503
# 158.00473
# 317.2154
# 111.724434
# 202.3563
# 225.10068
# 281.96164
# 316.0782
# 156.86752
# 269.4522
# 331.99927
# 252.39394
# 295.60828
# 303.5688
# 189.84688
# 204.63072
# 165.96526
# 339.9598
# 261.4917
# 125.24136
# 217.14014
# 136.50546
# 336.54816
# 198.94461
# 271.72665
# 313.80383
# 164.82805
# 109.47162
# 135.37904
# 156.86752
# 212.59125
# 325.176
# 252.39394
# 94.828285
# 184.1608
# 138.75827
# 247.84503
# ...

# %%
previsioni = np.array(previsioni)

# %%
err = abs(previsioni - y_test)

# %%
err_mean = np.mean(err)

# %%
err_mean
# Out:
# 38.33055076599121

# %%
mape = np.mean((err / y_test) * 100)

# %%
mape
# Out:
# 37.282548587872995
